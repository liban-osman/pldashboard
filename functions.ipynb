# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import asyncio
import json
import aiohttp
from understat import Understat
import nest_asyncio

# %%
def players():    
    nest_asyncio.apply()
    async def all_understat_players():
        async with aiohttp.ClientSession() as session:
            understat = Understat(session)
            players = await understat.get_league_players(
                "epl",
                2024,
            )
            return json.dumps(players)

    players = asyncio.run(all_understat_players())
    players = json.loads(players)
    return players

# %%
e = players()

# %%
e
# Out:
# [{'id': '1250',
#   'player_name': 'Mohamed Salah',
#   'games': '20',
#   'time': '1768',
#   'goals': '14',
#   'xG': '13.610325902700424',
#   'assists': '8',
#   'xA': '9.57847910746932',
#   'shots': '65',
#   'key_passes': '47',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Liverpool',
#   'npg': '10',
#   'npxG': '9.043387070298195',
#   'xGChain': '19.68034301698208',
#   'xGBuildup': '5.720102474093437'},
#  {'id': '8260',
#   'player_name': 'Erling Haaland',
#   'games': '15',
#   'time': '1305',
#   'goals': '14',
#   'xG': '16.727499932050705',
#   'assists': '4',
#   'xA': '3.2472310978919268',
#   'shots': '58',
#   'key_passes': '16',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Manchester City',
#   'npg': '11',
#   'npxG': '13.68282476067543',
#   'xGChain': '16.214465029537678',
#   'xGBuildup': '1.3705047406256199'},
#  {'id': '453',
#   'player_name': 'Son Heung-Min',
#   'games': '20',
#   'time': '1739',
#   'goals': '12',
#   'xG': '7.47495724260807',
#   'assists': '5',
#   'xA': '6.843130592256784',
#   'shots': '52',
#   'key_passes': '37',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Tottenham',
#   'npg': '11',
#   'npxG': '6.713788405060768',
#   'xGChain': '16.887082293629646',
#   'xGBuildup': '6.178518561646342'},
#  {'id': '1679',
#   'player_name': 'Dominic Solanke',
#   'games': '19',
#   'time': '1708',
#   'goals': '12',
#   'xG': '12.378114826977253',
#   'assists': '1',
#   'xA': '0.9976950995624065',
#   'shots': '66',
#   'key_passes': '14',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Bournemouth',
#   'npg': '11',
#   'npxG': '11.61694597452879',
#   'xGChain': '12.262300044298172',
#   'xGBuildup': '1.8974752612411976'},
#  {'id': '1776',
#   'player_name': 'Jarrod Bowen',
#   'games': '19',
#   'time': '1710',
#   'goals': '11',
#   'xG': '8.29572493582964',
#   'assists': '2',
#   'xA': '3.144163405522704',
#   'shots': '47',
#   'key_passes': '14',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'West Ham',
#   'npg': '11',
#   'npxG': '8.29572493582964',
#   'xGChain': '9.910744827240705',
#   'xGBuildup': '1.9265567287802696'},
#  {'id': '5232',
#   'player_name': 'Alexander Isak',
#   'games': '16',
#   'time': '1161',
#   'goals': '10',
#   'xG': '10.588220298290253',
#   'assists': '0',
#   'xA': '1.3252181969583035',
#   'shots': '37',
#   'key_passes': '11',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '8',
#   'npxG': '9.065882563591003',
#   'xGChain': '11.43273314833641',
#   'xGBuildup': '2.939927790313959'},
#  {'id': '8845',
#   'player_name': 'Hee-Chan Hwang',
#   'games': '20',
#   'time': '1466',
#   'goals': '10',
#   'xG': '6.790349626913667',
#   'assists': '3',
#   'xA': '3.0366309229284525',
#   'shots': '35',
#   'key_passes': '14',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '9',
#   'npxG': '6.029180759564042',
#   'xGChain': '9.669545919634402',
#   'xGBuildup': '2.148992163129151'},
#  {'id': '8497',
#   'player_name': 'Cole Palmer',
#   'games': '18',
#   'time': '1235',
#   'goals': '9',
#   'xG': '7.731454914435744',
#   'assists': '4',
#   'xA': '5.087213238701224',
#   'shots': '41',
#   'key_passes': '28',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea,Manchester City',
#   'npg': '4',
#   'npxG': '3.925610648468137',
#   'xGChain': '11.595409283414483',
#   'xGBuildup': '5.120687790215015'},
#  {'id': '8865',
#   'player_name': 'Ollie Watkins',
#   'games': '20',
#   'time': '1779',
#   'goals': '9',
#   'xG': '10.453795365989208',
#   'assists': '8',
#   'xA': '4.449759863317013',
#   'shots': '55',
#   'key_passes': '30',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Aston Villa',
#   'npg': '9',
#   'npxG': '10.453795365989208',
#   'xGChain': '15.558012336492538',
#   'xGBuildup': '2.1048314729705453'},
#  {'id': '468',
#   'player_name': 'Callum Wilson',
#   'games': '14',
#   'time': '710',
#   'goals': '7',
#   'xG': '8.662500880658627',
#   'assists': '1',
#   'xA': '0.42866930179297924',
#   'shots': '31',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '5',
#   'npxG': '7.14016330987215',
#   'xGChain': '7.621083067730069',
#   'xGBuildup': '0.8389131352305412'},
#  {'id': '4456',
#   'player_name': 'Chris Wood',
#   'games': '18',
#   'time': '706',
#   'goals': '7',
#   'xG': '5.063202641904354',
#   'assists': '1',
#   'xA': '1.0724100936204195',
#   'shots': '19',
#   'key_passes': '12',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Nottingham Forest',
#   'npg': '7',
#   'npxG': '5.063202641904354',
#   'xGChain': '5.99279666878283',
#   'xGBuildup': '0.21865982562303543'},
#  {'id': '6552',
#   'player_name': 'Bryan Mbeumo',
#   'games': '15',
#   'time': '1289',
#   'goals': '7',
#   'xG': '7.574615128338337',
#   'assists': '3',
#   'xA': '2.8948017433285713',
#   'shots': '41',
#   'key_passes': '22',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Brentford',
#   'npg': '4',
#   'npxG': '5.291108556091785',
#   'xGChain': '9.410030841827393',
#   'xGBuildup': '3.1749180927872658'},
#  {'id': '8150',
#   'player_name': 'Anthony Gordon',
#   'games': '20',
#   'time': '1705',
#   'goals': '7',
#   'xG': '6.108674101531506',
#   'assists': '5',
#   'xA': '4.997361587360501',
#   'shots': '44',
#   'key_passes': '22',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '7',
#   'npxG': '6.108674101531506',
#   'xGChain': '15.792282551527023',
#   'xGBuildup': '6.617116902023554'},
#  {'id': '8272',
#   'player_name': 'João Pedro',
#   'games': '20',
#   'time': '1120',
#   'goals': '7',
#   'xG': '6.923017270863056',
#   'assists': '2',
#   'xA': '2.871623874641955',
#   'shots': '40',
#   'key_passes': '18',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '3.8784161042422056',
#   'xGChain': '9.901699712499976',
#   'xGBuildup': '4.285971317440271'},
#  {'id': '10048',
#   'player_name': 'Nicolas Jackson',
#   'games': '19',
#   'time': '1458',
#   'goals': '7',
#   'xG': '11.180736033245921',
#   'assists': '2',
#   'xA': '2.957573415711522',
#   'shots': '45',
#   'key_passes': '16',
#   'yellow_cards': '8',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '7',
#   'npxG': '11.180736033245921',
#   'xGChain': '14.183117497712374',
#   'xGBuildup': '2.219442430883646'},
#  {'id': '1726',
#   'player_name': 'Abdoulaye Doucouré',
#   'games': '17',
#   'time': '1460',
#   'goals': '6',
#   'xG': '7.047202989459038',
#   'assists': '0',
#   'xA': '2.036896336823702',
#   'shots': '28',
#   'key_passes': '22',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Everton',
#   'npg': '6',
#   'npxG': '7.047202989459038',
#   'xGChain': '9.405437964946032',
#   'xGBuildup': '3.6784230321645737'},
#  {'id': '3635',
#   'player_name': 'Bernardo Silva',
#   'games': '17',
#   'time': '1433',
#   'goals': '6',
#   'xG': '2.3876431211829185',
#   'assists': '4',
#   'xA': '4.979102602228522',
#   'shots': '19',
#   'key_passes': '33',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '6',
#   'npxG': '2.3876431211829185',
#   'xGChain': '14.212061738595366',
#   'xGBuildup': '8.989704987034202'},
#  {'id': '3697',
#   'player_name': 'Odsonne Edouard',
#   'games': '15',
#   'time': '1270',
#   'goals': '6',
#   'xG': '6.131767854094505',
#   'assists': '0',
#   'xA': '0.864791008643806',
#   'shots': '39',
#   'key_passes': '13',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Crystal Palace',
#   'npg': '6',
#   'npxG': '6.131767854094505',
#   'xGChain': '6.33973165974021',
#   'xGBuildup': '1.469034243375063'},
#  {'id': '5221',
#   'player_name': 'Leon Bailey',
#   'games': '18',
#   'time': '872',
#   'goals': '6',
#   'xG': '3.2635028287768364',
#   'assists': '5',
#   'xA': '4.156177133321762',
#   'shots': '27',
#   'key_passes': '19',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Aston Villa',
#   'npg': '6',
#   'npxG': '3.2635028287768364',
#   'xGChain': '8.750119514763355',
#   'xGBuildup': '2.968475740402937'},
#  {'id': '6026',
#   'player_name': 'Richarlison',
#   'games': '17',
#   'time': '946',
#   'goals': '6',
#   'xG': '6.742483241483569',
#   'assists': '3',
#   'xA': '1.0897221639752388',
#   'shots': '39',
#   'key_passes': '9',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Tottenham',
#   'npg': '6',
#   'npxG': '6.742483241483569',
#   'xGChain': '8.496763460338116',
#   'xGBuildup': '1.4466600809246302'},
#  {'id': '6122',
#   'player_name': 'Douglas Luiz',
#   'games': '19',
#   'time': '1678',
#   'goals': '6',
#   'xG': '5.316661614924669',
#   'assists': '3',
#   'xA': '2.5393043514341116',
#   'shots': '36',
#   'key_passes': '27',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Aston Villa',
#   'npg': '2',
#   'npxG': '2.2719862572848797',
#   'xGChain': '10.123004015535116',
#   'xGBuildup': '8.010031690821052'},
#  {'id': '7080',
#   'player_name': 'Matheus Cunha',
#   'games': '20',
#   'time': '1718',
#   'goals': '6',
#   'xG': '5.866328570060432',
#   'assists': '5',
#   'xA': '3.1632621362805367',
#   'shots': '47',
#   'key_passes': '21',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '6',
#   'npxG': '5.866328570060432',
#   'xGChain': '8.991567961871624',
#   'xGBuildup': '1.5023581953719258'},
#  {'id': '7322',
#   'player_name': 'Bukayo Saka',
#   'games': '19',
#   'time': '1682',
#   'goals': '6',
#   'xG': '7.936890881508589',
#   'assists': '6',
#   'xA': '6.405137315392494',
#   'shots': '49',
#   'key_passes': '48',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Arsenal',
#   'npg': '4',
#   'npxG': '6.4145532585680485',
#   'xGChain': '16.48086705803871',
#   'xGBuildup': '7.043163921684027'},
#  {'id': '10177',
#   'player_name': 'Evan Ferguson',
#   'games': '18',
#   'time': '977',
#   'goals': '6',
#   'xG': '3.116366809234023',
#   'assists': '0',
#   'xA': '0.6063905879855156',
#   'shots': '26',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brighton',
#   'npg': '6',
#   'npxG': '3.116366809234023',
#   'xGChain': '5.664436191320419',
#   'xGBuildup': '2.0616533048450947'},
#  {'id': '10846',
#   'player_name': 'Julián Álvarez',
#   'games': '20',
#   'time': '1711',
#   'goals': '6',
#   'xG': '7.483333542943001',
#   'assists': '5',
#   'xA': '4.240109716542065',
#   'shots': '56',
#   'key_passes': '47',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Manchester City',
#   'npg': '5',
#   'npxG': '6.722164645791054',
#   'xGChain': '16.289245061576366',
#   'xGBuildup': '8.531317099928856'},
#  {'id': '12027',
#   'player_name': 'Mohammed Kudus',
#   'games': '16',
#   'time': '960',
#   'goals': '6',
#   'xG': '1.8171145021915436',
#   'assists': '1',
#   'xA': '1.3321975693106651',
#   'shots': '21',
#   'key_passes': '11',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'West Ham',
#   'npg': '6',
#   'npxG': '1.8171145021915436',
#   'xGChain': '4.752290626987815',
#   'xGBuildup': '2.4629297740757465'},
#  {'id': '618',
#   'player_name': 'Raheem Sterling',
#   'games': '19',
#   'time': '1523',
#   'goals': '5',
#   'xG': '5.865220725536346',
#   'assists': '3',
#   'xA': '3.692453084513545',
#   'shots': '34',
#   'key_passes': '22',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '5',
#   'npxG': '5.865220725536346',
#   'xGChain': '13.737415539100766',
#   'xGBuildup': '5.922000112012029'},
#  {'id': '4105',
#   'player_name': 'Raúl Jiménez',
#   'games': '18',
#   'time': '1237',
#   'goals': '5',
#   'xG': '4.338343150913715',
#   'assists': '0',
#   'xA': '1.4086075089871883',
#   'shots': '34',
#   'key_passes': '9',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Fulham',
#   'npg': '5',
#   'npxG': '4.338343150913715',
#   'xGChain': '5.841095481067896',
#   'xGBuildup': '1.3985759727656841'},
#  {'id': '5560',
#   'player_name': 'Scott McTominay',
#   'games': '17',
#   'time': '1109',
#   'goals': '5',
#   'xG': '4.066541066393256',
#   'assists': '0',
#   'xA': '0.4636244382709265',
#   'shots': '28',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester United',
#   'npg': '5',
#   'npxG': '4.066541066393256',
#   'xGChain': '4.750331548973918',
#   'xGBuildup': '1.3749198503792286'},
#  {'id': '6055',
#   'player_name': 'Phil Foden',
#   'games': '20',
#   'time': '1611',
#   'goals': '5',
#   'xG': '5.005221089348197',
#   'assists': '6',
#   'xA': '5.096725314855576',
#   'shots': '49',
#   'key_passes': '42',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester City',
#   'npg': '5',
#   'npxG': '5.005221089348197',
#   'xGChain': '15.203431889414787',
#   'xGBuildup': '9.089750515297055'},
#  {'id': '6482',
#   'player_name': 'Eddie Nketiah',
#   'games': '19',
#   'time': '956',
#   'goals': '5',
#   'xG': '4.617060862481594',
#   'assists': '1',
#   'xA': '0.6371538229286671',
#   'shots': '32',
#   'key_passes': '7',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal',
#   'npg': '5',
#   'npxG': '4.617060862481594',
#   'xGChain': '4.818891417235136',
#   'xGBuildup': '0.9136706292629242'},
#  {'id': '6691',
#   'player_name': 'Dejan Kulusevski',
#   'games': '19',
#   'time': '1693',
#   'goals': '5',
#   'xG': '2.9024968929588795',
#   'assists': '2',
#   'xA': '5.030836449936032',
#   'shots': '34',
#   'key_passes': '42',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Tottenham',
#   'npg': '5',
#   'npxG': '2.9024968929588795',
#   'xGChain': '13.003110483288765',
#   'xGBuildup': '7.025578789412975'},
#  {'id': '6854',
#   'player_name': 'Diogo Jota',
#   'games': '14',
#   'time': '678',
#   'goals': '5',
#   'xG': '3.9253063797950745',
#   'assists': '1',
#   'xA': '1.5711187589913607',
#   'shots': '24',
#   'key_passes': '14',
#   'yellow_cards': '1',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Liverpool',
#   'npg': '5',
#   'npxG': '3.9253063797950745',
#   'xGChain': '7.9896849393844604',
#   'xGBuildup': '4.9266655799001455'},
#  {'id': '7723',
#   'player_name': 'John McGinn',
#   'games': '20',
#   'time': '1742',
#   'goals': '5',
#   'xG': '2.9083894938230515',
#   'assists': '2',
#   'xA': '3.662117499858141',
#   'shots': '25',
#   'key_passes': '30',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Aston Villa',
#   'npg': '5',
#   'npxG': '2.9083894938230515',
#   'xGChain': '13.593573361635208',
#   'xGBuildup': '8.71016251668334'},
#  {'id': '8288',
#   'player_name': 'Tomas Soucek',
#   'games': '19',
#   'time': '1534',
#   'goals': '5',
#   'xG': '5.97108955308795',
#   'assists': '1',
#   'xA': '0.6327051762491465',
#   'shots': '25',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'West Ham',
#   'npg': '5',
#   'npxG': '5.97108955308795',
#   'xGChain': '7.554725036025047',
#   'xGBuildup': '3.3661038139835'},
#  {'id': '9948',
#   'player_name': 'Michael Olise',
#   'games': '9',
#   'time': '665',
#   'goals': '5',
#   'xG': '2.9752268474549055',
#   'assists': '1',
#   'xA': '2.2578294202685356',
#   'shots': '26',
#   'key_passes': '19',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Crystal Palace',
#   'npg': '4',
#   'npxG': '2.2140579763799906',
#   'xGChain': '4.5320023614913225',
#   'xGBuildup': '2.2123710457235575'},
#  {'id': '10720',
#   'player_name': 'Darwin Núñez',
#   'games': '19',
#   'time': '1118',
#   'goals': '5',
#   'xG': '11.132159125991166',
#   'assists': '6',
#   'xA': '3.8916123947128654',
#   'shots': '58',
#   'key_passes': '19',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Liverpool',
#   'npg': '5',
#   'npxG': '11.132159125991166',
#   'xGChain': '14.982022352516651',
#   'xGBuildup': '2.60064285248518'},
#  {'id': '11718',
#   'player_name': 'Elijah Adebayo',
#   'games': '20',
#   'time': '900',
#   'goals': '5',
#   'xG': '3.6024141926318407',
#   'assists': '0',
#   'xA': '0.7467418294399977',
#   'shots': '18',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Luton',
#   'npg': '5',
#   'npxG': '3.6024141926318407',
#   'xGChain': '4.79135718382895',
#   'xGBuildup': '0.8263525683432817'},
#  {'id': '700',
#   'player_name': 'Willian',
#   'games': '17',
#   'time': '1181',
#   'goals': '4',
#   'xG': '3.8347914731130004',
#   'assists': '1',
#   'xA': '1.7466816352680326',
#   'shots': '28',
#   'key_passes': '24',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Fulham',
#   'npg': '2',
#   'npxG': '2.312453798018396',
#   'xGChain': '8.445149272680283',
#   'xGBuildup': '5.642697710543871'},
#  {'id': '1299',
#   'player_name': 'Mario Lemina',
#   'games': '17',
#   'time': '1492',
#   'goals': '4',
#   'xG': '3.0691163102164865',
#   'assists': '0',
#   'xA': '0.2353523187339306',
#   'shots': '26',
#   'key_passes': '4',
#   'yellow_cards': '7',
#   'red_cards': '1',
#   'position': 'M',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '4',
#   'npxG': '3.0691163102164865',
#   'xGChain': '4.000854138284922',
#   'xGBuildup': '2.9168977215886116'},
#  {'id': '2496',
#   'player_name': 'Rodri',
#   'games': '17',
#   'time': '1469',
#   'goals': '4',
#   'xG': '2.966092085465789',
#   'assists': '3',
#   'xA': '2.40580415353179',
#   'shots': '37',
#   'key_passes': '20',
#   'yellow_cards': '7',
#   'red_cards': '1',
#   'position': 'M',
#   'team_title': 'Manchester City',
#   'npg': '4',
#   'npxG': '2.966092085465789',
#   'xGChain': '15.092251479625702',
#   'xGBuildup': '12.360695481300354'},
#  {'id': '2517',
#   'player_name': 'Martin Odegaard',
#   'games': '17',
#   'time': '1516',
#   'goals': '4',
#   'xG': '3.4981173146516085',
#   'assists': '3',
#   'xA': '4.626325845718384',
#   'shots': '39',
#   'key_passes': '44',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Arsenal',
#   'npg': '2',
#   'npxG': '1.9758164267987013',
#   'xGChain': '12.874902367591858',
#   'xGBuildup': '9.011669270694256'},
#  {'id': '5220',
#   'player_name': 'Kai Havertz',
#   'games': '19',
#   'time': '1172',
#   'goals': '4',
#   'xG': '4.183988839387894',
#   'assists': '1',
#   'xA': '1.2460595481097698',
#   'shots': '25',
#   'key_passes': '16',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '3.422820009291172',
#   'xGChain': '8.503283105790615',
#   'xGBuildup': '4.655843121930957'},
#  {'id': '5786',
#   'player_name': 'Yoane Wissa',
#   'games': '19',
#   'time': '1588',
#   'goals': '4',
#   'xG': '6.614129316061735',
#   'assists': '1',
#   'xA': '1.7804004363715649',
#   'shots': '43',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brentford',
#   'npg': '4',
#   'npxG': '6.614129316061735',
#   'xGChain': '8.974249444901943',
#   'xGBuildup': '2.4045274388045073'},
#  {'id': '6556',
#   'player_name': 'Moussa Diaby',
#   'games': '20',
#   'time': '1335',
#   'goals': '4',
#   'xG': '4.027413081377745',
#   'assists': '4',
#   'xA': '5.209943886846304',
#   'shots': '35',
#   'key_passes': '27',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Aston Villa',
#   'npg': '4',
#   'npxG': '4.027413081377745',
#   'xGChain': '11.543777722865343',
#   'xGBuildup': '4.910003714263439'},
#  {'id': '6827',
#   'player_name': 'Bobby Reid',
#   'games': '19',
#   'time': '871',
#   'goals': '4',
#   'xG': '3.803046409972012',
#   'assists': '0',
#   'xA': '0.41242159344255924',
#   'shots': '18',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Fulham',
#   'npg': '4',
#   'npxG': '3.803046409972012',
#   'xGChain': '3.6716624395921826',
#   'xGBuildup': '1.215634698048234'},
#  {'id': '7498',
#   'player_name': 'Lyle Foster',
#   'games': '12',
#   'time': '994',
#   'goals': '4',
#   'xG': '2.4960236698389053',
#   'assists': '3',
#   'xA': '0.9377795774489641',
#   'shots': '18',
#   'key_passes': '10',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Burnley',
#   'npg': '4',
#   'npxG': '2.4960236698389053',
#   'xGChain': '3.658179145306349',
#   'xGBuildup': '0.9448364581912756'},
#  {'id': '7814',
#   'player_name': 'Taiwo Awoniyi',
#   'games': '10',
#   'time': '688',
#   'goals': '4',
#   'xG': '3.715350016951561',
#   'assists': '2',
#   'xA': '0.6755558587610722',
#   'shots': '12',
#   'key_passes': '9',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Nottingham Forest',
#   'npg': '4',
#   'npxG': '3.715350016951561',
#   'xGChain': '4.271361701190472',
#   'xGBuildup': '1.0210123481228948'},
#  {'id': '9524',
#   'player_name': 'Anthony Elanga',
#   'games': '20',
#   'time': '1353',
#   'goals': '4',
#   'xG': '3.1140028964728117',
#   'assists': '6',
#   'xA': '4.6477286368608475',
#   'shots': '35',
#   'key_passes': '19',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '4',
#   'npxG': '3.1140028964728117',
#   'xGChain': '9.760287281125784',
#   'xGBuildup': '2.8164664208889008'},
#  {'id': '11701',
#   'player_name': 'Zeki Amdouni',
#   'games': '20',
#   'time': '1531',
#   'goals': '4',
#   'xG': '3.9232411235570908',
#   'assists': '1',
#   'xA': '1.178643874824047',
#   'shots': '33',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Burnley',
#   'npg': '4',
#   'npxG': '3.9232411235570908',
#   'xGChain': '5.937796823680401',
#   'xGBuildup': '2.276346266269684'},
#  {'id': '11710',
#   'player_name': 'Simon Adingra',
#   'games': '17',
#   'time': '1155',
#   'goals': '4',
#   'xG': '2.9683602191507816',
#   'assists': '1',
#   'xA': '1.7514075338840485',
#   'shots': '20',
#   'key_passes': '18',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Brighton',
#   'npg': '4',
#   'npxG': '2.9683602191507816',
#   'xGChain': '6.599735658615828',
#   'xGBuildup': '2.573754632845521'},
#  {'id': '11717',
#   'player_name': 'Carlton Morris',
#   'games': '20',
#   'time': '1268',
#   'goals': '4',
#   'xG': '5.101757202297449',
#   'assists': '2',
#   'xA': '0.9384258855134249',
#   'shots': '35',
#   'key_passes': '9',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Luton',
#   'npg': '2',
#   'npxG': '3.5794194675982',
#   'xGChain': '6.234991744160652',
#   'xGBuildup': '3.564909912645817'},
#  {'id': '239',
#   'player_name': 'Pascal Groß',
#   'games': '18',
#   'time': '1550',
#   'goals': '3',
#   'xG': '3.2966111712157726',
#   'assists': '6',
#   'xA': '4.212384800426662',
#   'shots': '35',
#   'key_passes': '50',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '3.2966111712157726',
#   'xGChain': '12.585024908185005',
#   'xGBuildup': '9.521034626290202'},
#  {'id': '500',
#   'player_name': 'Alex Iwobi',
#   'games': '18',
#   'time': '1302',
#   'goals': '3',
#   'xG': '3.7226694729179144',
#   'assists': '1',
#   'xA': '1.4090919205918908',
#   'shots': '36',
#   'key_passes': '20',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Everton,Fulham',
#   'npg': '3',
#   'npxG': '3.7226694729179144',
#   'xGChain': '8.697275310754776',
#   'xGBuildup': '5.117713296785951'},
#  {'id': '556',
#   'player_name': 'Marcus Rashford',
#   'games': '19',
#   'time': '1334',
#   'goals': '3',
#   'xG': '5.393615627661347',
#   'assists': '2',
#   'xA': '1.9994493909180164',
#   'shots': '42',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester United',
#   'npg': '2',
#   'npxG': '4.632446790114045',
#   'xGChain': '8.831173861399293',
#   'xGBuildup': '2.8092545457184315'},
#  {'id': '675',
#   'player_name': 'Jack Grealish',
#   'games': '12',
#   'time': '672',
#   'goals': '3',
#   'xG': '2.0509971976280212',
#   'assists': '1',
#   'xA': '2.3464410826563835',
#   'shots': '16',
#   'key_passes': '19',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '3',
#   'npxG': '2.0509971976280212',
#   'xGChain': '7.660753205418587',
#   'xGBuildup': '4.201451004482806'},
#  {'id': '843',
#   'player_name': 'James Ward-Prowse',
#   'games': '19',
#   'time': '1698',
#   'goals': '3',
#   'xG': '2.980880512855947',
#   'assists': '6',
#   'xA': '4.275119975209236',
#   'shots': '24',
#   'key_passes': '36',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'West Ham',
#   'npg': '3',
#   'npxG': '2.980880512855947',
#   'xGChain': '8.146866022609174',
#   'xGBuildup': '5.2532610129565'},
#  {'id': '1228',
#   'player_name': 'Bruno Fernandes',
#   'games': '19',
#   'time': '1710',
#   'goals': '3',
#   'xG': '4.839055153541267',
#   'assists': '3',
#   'xA': '6.651980118826032',
#   'shots': '47',
#   'key_passes': '54',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Manchester United',
#   'npg': '2',
#   'npxG': '3.3167173890396953',
#   'xGChain': '11.16520033031702',
#   'xGBuildup': '6.31614675372839'},
#  {'id': '1736',
#   'player_name': 'Oliver McBurnie',
#   'games': '11',
#   'time': '677',
#   'goals': '3',
#   'xG': '3.359126340597868',
#   'assists': '1',
#   'xA': '1.44778685644269',
#   'shots': '17',
#   'key_passes': '6',
#   'yellow_cards': '1',
#   'red_cards': '2',
#   'position': 'F S',
#   'team_title': 'Sheffield United',
#   'npg': '2',
#   'npxG': '2.597957443445921',
#   'xGChain': '3.6648588282987475',
#   'xGBuildup': '1.2522973036393523'},
#  {'id': '5543',
#   'player_name': 'Gabriel Jesus',
#   'games': '15',
#   'time': '956',
#   'goals': '3',
#   'xG': '5.046736657619476',
#   'assists': '1',
#   'xA': '1.5707852356135845',
#   'shots': '32',
#   'key_passes': '16',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '5.046736657619476',
#   'xGChain': '9.61802700534463',
#   'xGBuildup': '3.933274481445551'},
#  {'id': '5553',
#   'player_name': 'Declan Rice',
#   'games': '20',
#   'time': '1756',
#   'goals': '3',
#   'xG': '1.169261553324759',
#   'assists': '1',
#   'xA': '1.6992180813103914',
#   'shots': '27',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '1.169261553324759',
#   'xGChain': '10.052008866332471',
#   'xGBuildup': '8.83073178678751'},
#  {'id': '5555',
#   'player_name': 'Dominic Calvert-Lewin',
#   'games': '16',
#   'time': '1103',
#   'goals': '3',
#   'xG': '7.067315865308046',
#   'assists': '0',
#   'xA': '0.7324996585957706',
#   'shots': '33',
#   'key_passes': '10',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Everton',
#   'npg': '3',
#   'npxG': '7.067315865308046',
#   'xGChain': '6.4377016462385654',
#   'xGBuildup': '0.6413102764636278'},
#  {'id': '6049',
#   'player_name': 'Solly March',
#   'games': '7',
#   'time': '571',
#   'goals': '3',
#   'xG': '2.7198847085237503',
#   'assists': '1',
#   'xA': '0.9913322664797306',
#   'shots': '14',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '2.7198847085237503',
#   'xGChain': '4.9072911739349365',
#   'xGBuildup': '2.40057972073555'},
#  {'id': '6818',
#   'player_name': 'James Maddison',
#   'games': '11',
#   'time': '909',
#   'goals': '3',
#   'xG': '2.944616189226508',
#   'assists': '5',
#   'xA': '3.4641558043658733',
#   'shots': '27',
#   'key_passes': '31',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Tottenham',
#   'npg': '3',
#   'npxG': '2.944616189226508',
#   'xGChain': '9.78583274781704',
#   'xGBuildup': '5.331316661089659'},
#  {'id': '7166',
#   'player_name': 'Mathias Jensen',
#   'games': '14',
#   'time': '1037',
#   'goals': '3',
#   'xG': '0.48332162480801344',
#   'assists': '2',
#   'xA': '2.5002479068934917',
#   'shots': '8',
#   'key_passes': '20',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Brentford',
#   'npg': '3',
#   'npxG': '0.48332162480801344',
#   'xGChain': '5.923113073222339',
#   'xGBuildup': '5.234428940340877'},
#  {'id': '7218',
#   'player_name': 'Cristian Romero',
#   'games': '15',
#   'time': '1176',
#   'goals': '3',
#   'xG': '0.9532680846750736',
#   'assists': '0',
#   'xA': '0.23308596201241016',
#   'shots': '10',
#   'key_passes': '5',
#   'yellow_cards': '4',
#   'red_cards': '1',
#   'position': 'D',
#   'team_title': 'Tottenham',
#   'npg': '3',
#   'npxG': '0.9532680846750736',
#   'xGChain': '9.660888437181711',
#   'xGBuildup': '9.596516583114862'},
#  {'id': '7420',
#   'player_name': 'Miguel Almirón',
#   'games': '21',
#   'time': '1462',
#   'goals': '3',
#   'xG': '4.312681986019015',
#   'assists': '1',
#   'xA': '1.8104861080646515',
#   'shots': '34',
#   'key_passes': '19',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '3',
#   'npxG': '4.312681986019015',
#   'xGChain': '9.506275802850723',
#   'xGBuildup': '4.202272681519389'},
#  {'id': '7698',
#   'player_name': 'Leandro Trossard',
#   'games': '16',
#   'time': '640',
#   'goals': '3',
#   'xG': '4.079841900616884',
#   'assists': '1',
#   'xA': '2.0012934990227222',
#   'shots': '23',
#   'key_passes': '13',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '4.079841900616884',
#   'xGChain': '6.9635259713977575',
#   'xGBuildup': '1.9624435752630234'},
#  {'id': '8323',
#   'player_name': 'Josh Brownhill',
#   'games': '20',
#   'time': '1588',
#   'goals': '3',
#   'xG': '0.8141022082418203',
#   'assists': '0',
#   'xA': '0.7887266166508198',
#   'shots': '18',
#   'key_passes': '17',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Burnley',
#   'npg': '3',
#   'npxG': '0.8141022082418203',
#   'xGChain': '3.273689813911915',
#   'xGBuildup': '2.4721789341419935'},
#  {'id': '8706',
#   'player_name': 'Eberechi Eze',
#   'games': '14',
#   'time': '1000',
#   'goals': '3',
#   'xG': '4.431468084454536',
#   'assists': '1',
#   'xA': '2.8187928311526775',
#   'shots': '40',
#   'key_passes': '27',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '3.6702992394566536',
#   'xGChain': '6.651544392108917',
#   'xGBuildup': '2.752619894221425'},
#  {'id': '9912',
#   'player_name': 'Cameron Archer',
#   'games': '18',
#   'time': '1340',
#   'goals': '3',
#   'xG': '3.0077435560524464',
#   'assists': '0',
#   'xA': '2.0871694944798946',
#   'shots': '24',
#   'key_passes': '18',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Aston Villa,Sheffield United',
#   'npg': '3',
#   'npxG': '3.0077435560524464',
#   'xGChain': '5.696906249038875',
#   'xGBuildup': '0.6516845105215907'},
#  {'id': '10408',
#   'player_name': 'Luis Díaz',
#   'games': '19',
#   'time': '1191',
#   'goals': '3',
#   'xG': '3.837191777303815',
#   'assists': '1',
#   'xA': '2.0027750954031944',
#   'shots': '35',
#   'key_passes': '22',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Liverpool',
#   'npg': '3',
#   'npxG': '3.837191777303815',
#   'xGChain': '8.607677537947893',
#   'xGBuildup': '4.547042828053236'},
#  {'id': '10552',
#   'player_name': 'Alejandro Garnacho',
#   'games': '18',
#   'time': '1066',
#   'goals': '3',
#   'xG': '3.6620294004678726',
#   'assists': '2',
#   'xA': '1.613000150769949',
#   'shots': '43',
#   'key_passes': '18',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester United',
#   'npg': '3',
#   'npxG': '3.6620294004678726',
#   'xGChain': '6.675775498151779',
#   'xGBuildup': '1.863478645682335'},
#  {'id': '10806',
#   'player_name': 'Kaoru Mitoma',
#   'games': '17',
#   'time': '1308',
#   'goals': '3',
#   'xG': '4.136269833892584',
#   'assists': '4',
#   'xA': '2.9180683754384518',
#   'shots': '31',
#   'key_passes': '23',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '4.136269833892584',
#   'xGChain': '12.729066520929337',
#   'xGBuildup': '7.843828905373812'},
#  {'id': '10822',
#   'player_name': 'Wilson Odobert',
#   'games': '12',
#   'time': '677',
#   'goals': '3',
#   'xG': '0.8061727080494165',
#   'assists': '1',
#   'xA': '1.4515807460993528',
#   'shots': '15',
#   'key_passes': '11',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Burnley',
#   'npg': '3',
#   'npxG': '0.8061727080494165',
#   'xGChain': '2.765665901824832',
#   'xGBuildup': '0.827910590916872'},
#  {'id': '11296',
#   'player_name': 'Cody Gakpo',
#   'games': '18',
#   'time': '815',
#   'goals': '3',
#   'xG': '3.9826766587793827',
#   'assists': '1',
#   'xA': '0.5533700436353683',
#   'shots': '26',
#   'key_passes': '10',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Liverpool',
#   'npg': '3',
#   'npxG': '3.9826766587793827',
#   'xGChain': '5.956691961735487',
#   'xGBuildup': '2.4674469344317913'},
#  {'id': '11305',
#   'player_name': 'Mykhailo Mudryk',
#   'games': '17',
#   'time': '787',
#   'goals': '3',
#   'xG': '2.2611535973846912',
#   'assists': '1',
#   'xA': '1.4049776643514633',
#   'shots': '15',
#   'key_passes': '14',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '3',
#   'npxG': '2.2611535973846912',
#   'xGChain': '4.177526333369315',
#   'xGBuildup': '1.2654564678668976'},
#  {'id': '11363',
#   'player_name': 'Antoine Semenyo',
#   'games': '16',
#   'time': '882',
#   'goals': '3',
#   'xG': '2.4580556955188513',
#   'assists': '1',
#   'xA': '1.8391491137444973',
#   'shots': '33',
#   'key_passes': '11',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Bournemouth',
#   'npg': '3',
#   'npxG': '2.4580556955188513',
#   'xGChain': '6.136833339929581',
#   'xGBuildup': '1.9559768363833427'},
#  {'id': '87',
#   'player_name': 'Joelinton',
#   'games': '16',
#   'time': '1154',
#   'goals': '2',
#   'xG': '2.0550636127591133',
#   'assists': '1',
#   'xA': '1.9260431751608849',
#   'shots': '15',
#   'key_passes': '18',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '2.0550636127591133',
#   'xGChain': '7.462845517322421',
#   'xGBuildup': '4.510361844673753'},
#  {'id': '501',
#   'player_name': 'Danny Welbeck',
#   'games': '12',
#   'time': '619',
#   'goals': '2',
#   'xG': '1.8282979186624289',
#   'assists': '0',
#   'xA': '0.706577192991972',
#   'shots': '15',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Brighton',
#   'npg': '2',
#   'npxG': '1.8282979186624289',
#   'xGChain': '5.324061509221792',
#   'xGBuildup': '3.7471321634948254'},
#  {'id': '531',
#   'player_name': 'Michail Antonio',
#   'games': '12',
#   'time': '859',
#   'goals': '2',
#   'xG': '1.9163854327052832',
#   'assists': '2',
#   'xA': '0.9527668282389641',
#   'shots': '9',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'West Ham',
#   'npg': '2',
#   'npxG': '1.9163854327052832',
#   'xGChain': '5.270372709259391',
#   'xGBuildup': '2.401220466941595'},
#  {'id': '579',
#   'player_name': 'Nathan Aké',
#   'games': '16',
#   'time': '1098',
#   'goals': '2',
#   'xG': '1.3204994723200798',
#   'assists': '1',
#   'xA': '1.568371705710888',
#   'shots': '15',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '1.3204994723200798',
#   'xGChain': '6.5931935384869576',
#   'xGBuildup': '5.554286040365696'},
#  {'id': '592',
#   'player_name': 'Ross Barkley',
#   'games': '15',
#   'time': '1162',
#   'goals': '2',
#   'xG': '1.5443060453981161',
#   'assists': '1',
#   'xA': '2.1783274598419666',
#   'shots': '35',
#   'key_passes': '17',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Luton',
#   'npg': '2',
#   'npxG': '1.5443060453981161',
#   'xGChain': '4.6657176874578',
#   'xGBuildup': '3.0914752949029207'},
#  {'id': '672',
#   'player_name': 'Jordan Ayew',
#   'games': '19',
#   'time': '1557',
#   'goals': '2',
#   'xG': '3.114279456436634',
#   'assists': '5',
#   'xA': '3.983744007535279',
#   'shots': '31',
#   'key_passes': '16',
#   'yellow_cards': '4',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '3.114279456436634',
#   'xGChain': '7.141842287033796',
#   'xGBuildup': '3.52212190721184'},
#  {'id': '844',
#   'player_name': 'Jay Rodriguez',
#   'games': '13',
#   'time': '690',
#   'goals': '2',
#   'xG': '3.9125491455197334',
#   'assists': '1',
#   'xA': '0.14750910177826881',
#   'shots': '18',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Burnley',
#   'npg': '1',
#   'npxG': '3.151380307972431',
#   'xGChain': '3.697810996323824',
#   'xGBuildup': '0.654015134088695'},
#  {'id': '1791',
#   'player_name': 'Trent Alexander-Arnold',
#   'games': '18',
#   'time': '1508',
#   'goals': '2',
#   'xG': '1.8993023708462715',
#   'assists': '3',
#   'xA': '5.973722470924258',
#   'shots': '29',
#   'key_passes': '49',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Liverpool',
#   'npg': '2',
#   'npxG': '1.8993023708462715',
#   'xGChain': '11.573892042040825',
#   'xGBuildup': '8.901589676737785'},
#  {'id': '3621',
#   'player_name': 'Neal Maupay',
#   'games': '16',
#   'time': '765',
#   'goals': '2',
#   'xG': '5.165133114904165',
#   'assists': '3',
#   'xA': '1.4316930631175637',
#   'shots': '29',
#   'key_passes': '10',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brentford,Everton',
#   'npg': '2',
#   'npxG': '5.165133114904165',
#   'xGChain': '8.070751886814833',
#   'xGBuildup': '2.0382075533270836'},
#  {'id': '5136',
#   'player_name': 'Estupiñán',
#   'games': '8',
#   'time': '630',
#   'goals': '2',
#   'xG': '0.9772415244951844',
#   'assists': '3',
#   'xA': '2.6487050093710423',
#   'shots': '9',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Brighton',
#   'npg': '2',
#   'npxG': '0.9772415244951844',
#   'xGChain': '6.447533935308456',
#   'xGBuildup': '4.532369887456298'},
#  {'id': '5355',
#   'player_name': 'Jacob Bruun Larsen',
#   'games': '17',
#   'time': '437',
#   'goals': '2',
#   'xG': '1.0551242250949144',
#   'assists': '0',
#   'xA': '0.5736029893159866',
#   'shots': '15',
#   'key_passes': '11',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Burnley',
#   'npg': '2',
#   'npxG': '1.0551242250949144',
#   'xGChain': '1.5870495131239295',
#   'xGBuildup': '0.5289615169167519'},
#  {'id': '5596',
#   'player_name': 'Harry Wilson',
#   'games': '21',
#   'time': '1087',
#   'goals': '2',
#   'xG': '1.4659033138304949',
#   'assists': '3',
#   'xA': '1.9476792868226767',
#   'shots': '23',
#   'key_passes': '12',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Fulham',
#   'npg': '2',
#   'npxG': '1.4659033138304949',
#   'xGChain': '4.559948775917292',
#   'xGBuildup': '2.769687367603183'},
#  {'id': '5681',
#   'player_name': 'Giovani Lo Celso',
#   'games': '10',
#   'time': '403',
#   'goals': '2',
#   'xG': '0.36788101494312286',
#   'assists': '2',
#   'xA': '0.6810179241001606',
#   'shots': '8',
#   'key_passes': '11',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Tottenham',
#   'npg': '2',
#   'npxG': '0.36788101494312286',
#   'xGChain': '2.3931398577988148',
#   'xGBuildup': '1.6784910075366497'},
#  {'id': '5735',
#   'player_name': 'Jean-Philippe Mateta',
#   'games': '17',
#   'time': '783',
#   'goals': '2',
#   'xG': '2.5698488652706146',
#   'assists': '3',
#   'xA': '2.2754142582416534',
#   'shots': '13',
#   'key_passes': '18',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Crystal Palace',
#   'npg': '1',
#   'npxG': '1.8086800053715706',
#   'xGChain': '4.303207032382488',
#   'xGBuildup': '0.6441928409039974'},
#  {'id': '6034',
#   'player_name': 'Philip Billing',
#   'games': '18',
#   'time': '1160',
#   'goals': '2',
#   'xG': '2.4570786003023386',
#   'assists': '2',
#   'xA': '2.362320439890027',
#   'shots': '23',
#   'key_passes': '18',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Bournemouth',
#   'npg': '2',
#   'npxG': '2.4570786003023386',
#   'xGChain': '5.83761315792799',
#   'xGBuildup': '2.5430262833833694'},
#  {'id': '6221',
#   'player_name': 'Pau Torres',
#   'games': '18',
#   'time': '1515',
#   'goals': '2',
#   'xG': '1.419058132916689',
#   'assists': '0',
#   'xA': '0.593196582980454',
#   'shots': '9',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Aston Villa',
#   'npg': '2',
#   'npxG': '1.419058132916689',
#   'xGChain': '7.397438765503466',
#   'xGBuildup': '7.1878891522064805'},
#  {'id': '6314',
#   'player_name': 'Joachim Andersen',
#   'games': '20',
#   'time': '1800',
#   'goals': '2',
#   'xG': '1.7387896096333861',
#   'assists': '1',
#   'xA': '1.3842538334429264',
#   'shots': '15',
#   'key_passes': '13',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '1.7387896096333861',
#   'xGChain': '6.313236977905035',
#   'xGBuildup': '5.905231669545174'},
#  {'id': '6490',
#   'player_name': 'Manuel Akanji',
#   'games': '15',
#   'time': '1261',
#   'goals': '2',
#   'xG': '0.7294066920876503',
#   'assists': '0',
#   'xA': '0.20319249480962753',
#   'shots': '7',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'D M S',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '0.7294066920876503',
#   'xGChain': '6.64615198969841',
#   'xGBuildup': '6.564498256891966'},
#  {'id': '6756',
#   'player_name': 'Dwight McNeil',
#   'games': '17',
#   'time': '1383',
#   'goals': '2',
#   'xG': '2.0381621811538935',
#   'assists': '4',
#   'xA': '5.772118408232927',
#   'shots': '31',
#   'key_passes': '27',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Everton',
#   'npg': '2',
#   'npxG': '2.0381621811538935',
#   'xGChain': '9.16857154481113',
#   'xGBuildup': '3.0818255096673965'},
#  {'id': '6857',
#   'player_name': 'Morgan Gibbs-White',
#   'games': '20',
#   'time': '1684',
#   'goals': '2',
#   'xG': '3.157539028674364',
#   'assists': '3',
#   'xA': '3.64912168122828',
#   'shots': '38',
#   'key_passes': '34',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '1',
#   'npxG': '2.3963702507317066',
#   'xGChain': '7.930424481630325',
#   'xGBuildup': '4.818683210760355'},
#  {'id': '6963',
#   'player_name': 'Justin Kluivert',
#   'games': '15',
#   'time': '859',
#   'goals': '2',
#   'xG': '1.942126251757145',
#   'assists': '0',
#   'xA': '0.6389709860086441',
#   'shots': '17',
#   'key_passes': '12',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Bournemouth',
#   'npg': '2',
#   'npxG': '1.942126251757145',
#   'xGChain': '4.405835717916489',
#   'xGBuildup': '1.9552713930606842'},
#  {'id': '7078',
#   'player_name': 'Sean Longstaff',
#   'games': '18',
#   'time': '1252',
#   'goals': '2',
#   'xG': '2.441285517066717',
#   'assists': '2',
#   'xA': '1.8700717370957136',
#   'shots': '17',
#   'key_passes': '12',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '2.441285517066717',
#   'xGChain': '9.028680991847068',
#   'xGBuildup': '6.250652589369565'},
#  {'id': '7365',
#   'player_name': 'Lucas Paquetá',
#   'games': '18',
#   'time': '1538',
#   'goals': '2',
#   'xG': '2.485358458943665',
#   'assists': '5',
#   'xA': '4.096440831199288',
#   'shots': '21',
#   'key_passes': '26',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'West Ham',
#   'npg': '1',
#   'npxG': '1.7241896213963628',
#   'xGChain': '7.715505393221974',
#   'xGBuildup': '3.421996710821986'},
#  {'id': '7382',
#   'player_name': 'Dan Burn',
#   'games': '16',
#   'time': '1363',
#   'goals': '2',
#   'xG': '2.7963957767933607',
#   'assists': '1',
#   'xA': '1.2153802886605263',
#   'shots': '11',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '2.7963957767933607',
#   'xGChain': '8.482227992266417',
#   'xGBuildup': '7.266240414232016'},
#  {'id': '7395',
#   'player_name': 'Carlos Vinicius',
#   'games': '13',
#   'time': '286',
#   'goals': '2',
#   'xG': '1.6243880316615105',
#   'assists': '0',
#   'xA': '0.5761066563427448',
#   'shots': '9',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Fulham',
#   'npg': '2',
#   'npxG': '1.6243880316615105',
#   'xGChain': '3.164248041808605',
#   'xGBuildup': '1.0699065858498216'},
#  {'id': '7752',
#   'player_name': 'Gabriel Martinelli',
#   'games': '18',
#   'time': '1342',
#   'goals': '2',
#   'xG': '3.109063096344471',
#   'assists': '2',
#   'xA': '2.0778841953724623',
#   'shots': '33',
#   'key_passes': '28',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal',
#   'npg': '2',
#   'npxG': '3.109063096344471',
#   'xGChain': '8.257571674883366',
#   'xGBuildup': '4.5036859614774585'},
#  {'id': '7762',
#   'player_name': 'Jean-Ricner Bellegarde',
#   'games': '11',
#   'time': '513',
#   'goals': '2',
#   'xG': '0.7283507473766804',
#   'assists': '1',
#   'xA': '0.639949057251215',
#   'shots': '8',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'D M S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '2',
#   'npxG': '0.7283507473766804',
#   'xGChain': '1.7606370151042938',
#   'xGBuildup': '0.922096561640501'},
#  {'id': '7967',
#   'player_name': 'Anssumane Fati',
#   'games': '9',
#   'time': '266',
#   'goals': '2',
#   'xG': '2.5193206518888474',
#   'assists': '0',
#   'xA': '0.4666708018630743',
#   'shots': '13',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Brighton',
#   'npg': '2',
#   'npxG': '2.5193206518888474',
#   'xGChain': '3.792191691696644',
#   'xGBuildup': '0.9694511890411377'},
#  {'id': '8252',
#   'player_name': 'Nicolás Domínguez',
#   'games': '11',
#   'time': '768',
#   'goals': '2',
#   'xG': '1.2517293933779001',
#   'assists': '0',
#   'xA': '0.03953762724995613',
#   'shots': '13',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '2',
#   'npxG': '1.2517293933779001',
#   'xGChain': '2.849966699257493',
#   'xGBuildup': '1.7506803199648857'},
#  {'id': '8635',
#   'player_name': 'Sven Botman',
#   'games': '10',
#   'time': '767',
#   'goals': '2',
#   'xG': '0.8160056136548519',
#   'assists': '1',
#   'xA': '0.9268479347229004',
#   'shots': '7',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '0.8160056136548519',
#   'xGChain': '3.56592907756567',
#   'xGBuildup': '3.56592907756567'},
#  {'id': '8720',
#   'player_name': 'Jack Harrison',
#   'games': '14',
#   'time': '1130',
#   'goals': '2',
#   'xG': '2.511421412229538',
#   'assists': '3',
#   'xA': '3.223566610366106',
#   'shots': '16',
#   'key_passes': '15',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Everton',
#   'npg': '2',
#   'npxG': '2.511421412229538',
#   'xGChain': '6.4511942863464355',
#   'xGBuildup': '1.783118700608611'},
#  {'id': '8812',
#   'player_name': 'Sasa Kalajdzic',
#   'games': '11',
#   'time': '132',
#   'goals': '2',
#   'xG': '1.3522434905171394',
#   'assists': '0',
#   'xA': '1.0801250115036964',
#   'shots': '4',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '2',
#   'npxG': '1.3522434905171394',
#   'xGChain': '2.5644532591104507',
#   'xGBuildup': '0.15924052149057388'},
#  {'id': '8864',
#   'player_name': 'Matthew Cash',
#   'games': '17',
#   'time': '1281',
#   'goals': '2',
#   'xG': '3.6146315736696124',
#   'assists': '1',
#   'xA': '1.7548393681645393',
#   'shots': '23',
#   'key_passes': '7',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Aston Villa',
#   'npg': '2',
#   'npxG': '3.6146315736696124',
#   'xGChain': '7.89841097407043',
#   'xGBuildup': '3.981618732213974'},
#  {'id': '8981',
#   'player_name': 'Jéremy Doku',
#   'games': '12',
#   'time': '811',
#   'goals': '2',
#   'xG': '1.4336399659514427',
#   'assists': '5',
#   'xA': '3.346791222691536',
#   'shots': '25',
#   'key_passes': '23',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Manchester City',
# ...
#   'time': '129',
#   'goals': '0',
#   'xG': '0.17524435929954052',
#   'assists': '0',
#   'xA': '0.04796999227255583',
#   'shots': '3',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0.17524435929954052',
#   'xGChain': '0.2102061901241541',
#   'xGBuildup': '0'},
#  {'id': '11704',
#   'player_name': 'Hjalmar Ekdal',
#   'games': '4',
#   'time': '188',
#   'goals': '0',
#   'xG': '0.047121964395046234',
#   'assists': '0',
#   'xA': '0.029761802405118942',
#   'shots': '1',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0.047121964395046234',
#   'xGChain': '0.25770944729447365',
#   'xGBuildup': '0.2279476448893547'},
#  {'id': '11707',
#   'player_name': 'Jurriën Timber',
#   'games': '1',
#   'time': '56',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Arsenal',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.19600066542625427',
#   'xGBuildup': '0.19600066542625427'},
#  {'id': '11709',
#   'player_name': 'Milos Kerkez',
#   'games': '15',
#   'time': '1176',
#   'goals': '0',
#   'xG': '0.21010207757353783',
#   'assists': '1',
#   'xA': '0.4846984539180994',
#   'shots': '4',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0.21010207757353783',
#   'xGChain': '3.313812365755439',
#   'xGBuildup': '2.9621767587959766'},
#  {'id': '11711',
#   'player_name': 'Bart Verbruggen',
#   'games': '9',
#   'time': '810',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.6037502512335777',
#   'xGBuildup': '1.6037502512335777'},
#  {'id': '11712',
#   'player_name': 'Thomas Kaminski',
#   'games': '20',
#   'time': '1800',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.6215326469391584',
#   'xGBuildup': '1.6215326469391584'},
#  {'id': '11713',
#   'player_name': 'Amari&#039;i Bell',
#   'games': '15',
#   'time': '1269',
#   'goals': '0',
#   'xG': '0.4993779337964952',
#   'assists': '0',
#   'xA': '0.31330371741205454',
#   'shots': '2',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0.4993779337964952',
#   'xGChain': '3.3982338942587376',
#   'xGBuildup': '2.5931895188987255'},
#  {'id': '11716',
#   'player_name': 'Pelly Ruddock Mpanzu',
#   'games': '16',
#   'time': '727',
#   'goals': '0',
#   'xG': '1.1216421527788043',
#   'assists': '0',
#   'xA': '0.49232789129018784',
#   'shots': '9',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '1.1216421527788043',
#   'xGChain': '2.2863366678357124',
#   'xGBuildup': '1.0027361810207367'},
#  {'id': '11721',
#   'player_name': 'Cauley Woodrow',
#   'games': '8',
#   'time': '51',
#   'goals': '0',
#   'xG': '0.3234410285949707',
#   'assists': '0',
#   'xA': '0.22639303468167782',
#   'shots': '5',
#   'key_passes': '5',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0.3234410285949707',
#   'xGChain': '0.4887387901544571',
#   'xGBuildup': '0.09787959977984428'},
#  {'id': '11722',
#   'player_name': 'Luke Berry',
#   'games': '3',
#   'time': '22',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11728',
#   'player_name': 'Calvin Bassey',
#   'games': '15',
#   'time': '1101',
#   'goals': '0',
#   'xG': '0.062184613198041916',
#   'assists': '0',
#   'xA': '0.10597540438175201',
#   'shots': '1',
#   'key_passes': '2',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'D S',
#   'team_title': 'Fulham',
#   'npg': '0',
#   'npxG': '0.062184613198041916',
#   'xGChain': '4.199875220656395',
#   'xGBuildup': '4.199875220656395'},
#  {'id': '11729',
#   'player_name': 'Bénie Traoré',
#   'games': '8',
#   'time': '360',
#   'goals': '0',
#   'xG': '0.3212226927280426',
#   'assists': '0',
#   'xA': '0.3953269124031067',
#   'shots': '1',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0.3212226927280426',
#   'xGChain': '1.2498194947838783',
#   'xGBuildup': '0.6901140883564949'},
#  {'id': '11730',
#   'player_name': 'Anis Ben Slimane',
#   'games': '10',
#   'time': '303',
#   'goals': '0',
#   'xG': '0.7071642503142357',
#   'assists': '0',
#   'xA': '0.48480090498924255',
#   'shots': '6',
#   'key_passes': '3',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0.7071642503142357',
#   'xGChain': '1.3688709884881973',
#   'xGBuildup': '0.2348492182791233'},
#  {'id': '11731',
#   'player_name': 'Andre Brooks',
#   'games': '8',
#   'time': '420',
#   'goals': '0',
#   'xG': '0.05996336415410042',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0.05996336415410042',
#   'xGChain': '0.04163395240902901',
#   'xGBuildup': '0'},
#  {'id': '11732',
#   'player_name': 'Auston Trusty',
#   'games': '15',
#   'time': '1179',
#   'goals': '0',
#   'xG': '0.39382290840148926',
#   'assists': '0',
#   'xA': '0.02272970974445343',
#   'shots': '3',
#   'key_passes': '1',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0.39382290840148926',
#   'xGChain': '0.4662561248987913',
#   'xGBuildup': '0.44807411544024944'},
#  {'id': '11772',
#   'player_name': 'Yehor Yarmolyuk',
#   'games': '11',
#   'time': '338',
#   'goals': '0',
#   'xG': '0.820180157199502',
#   'assists': '0',
#   'xA': '0.05148041993379593',
#   'shots': '6',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Brentford',
#   'npg': '0',
#   'npxG': '0.820180157199502',
#   'xGChain': '1.3377937618643045',
#   'xGBuildup': '0.5040281042456627'},
#  {'id': '11807',
#   'player_name': 'Ian Maatsen',
#   'games': '12',
#   'time': '169',
#   'goals': '0',
#   'xG': '0.6834889836609364',
#   'assists': '0',
#   'xA': '0.05732445325702429',
#   'shots': '5',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0.6834889836609364',
#   'xGChain': '1.3501509558409452',
#   'xGBuildup': '0.6530423145741224'},
#  {'id': '11808',
#   'player_name': 'Andrey Santos',
#   'games': '1',
#   'time': '3',
#   'goals': '0',
#   'xG': '0.07211316376924515',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0.07211316376924515',
#   'xGChain': '0.027800722047686577',
#   'xGBuildup': '0.027800722047686577'},
#  {'id': '11810',
#   'player_name': 'Mason Burstow',
#   'games': '2',
#   'time': '2',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11811',
#   'player_name': 'James McConnell',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Liverpool',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11926',
#   'player_name': 'Edson Álvarez',
#   'games': '17',
#   'time': '1355',
#   'goals': '0',
#   'xG': '0.32052907440811396',
#   'assists': '1',
#   'xA': '0.13583909254521132',
#   'shots': '9',
#   'key_passes': '3',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'West Ham',
#   'npg': '0',
#   'npxG': '0.32052907440811396',
#   'xGChain': '3.1805523801594973',
#   'xGBuildup': '2.997342899441719'},
#  {'id': '11984',
#   'player_name': 'Youssef Chermiti',
#   'games': '7',
#   'time': '35',
#   'goals': '0',
#   'xG': '0.07689288537949324',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Everton',
#   'npg': '0',
#   'npxG': '0.07689288537949324',
#   'xGChain': '0.15150949731469154',
#   'xGBuildup': '0.14069579914212227'},
#  {'id': '11987',
#   'player_name': 'Daniel Gore',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Manchester United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11998',
#   'player_name': 'Hannes Delcroix',
#   'games': '9',
#   'time': '376',
#   'goals': '0',
#   'xG': '0.23279432207345963',
#   'assists': '0',
#   'xA': '0.13672708347439766',
#   'shots': '4',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0.23279432207345963',
#   'xGChain': '1.0179676115512848',
#   'xGBuildup': '0.8812405355274677'},
#  {'id': '12032',
#   'player_name': 'Djordje Petrovic',
#   'games': '6',
#   'time': '452',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'GK S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.2569560706615448',
#   'xGBuildup': '0.2569560706615448'},
#  {'id': '12033',
#   'player_name': 'Deivid Washington',
#   'games': '1',
#   'time': '6',
#   'goals': '0',
#   'xG': '0.12518750131130219',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0.12518750131130219',
#   'xGChain': '0.12518750131130219',
#   'xGBuildup': '0'},
#  {'id': '12086',
#   'player_name': 'Alex Matos',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12094',
#   'player_name': 'Mike Trésor',
#   'games': '14',
#   'time': '376',
#   'goals': '0',
#   'xG': '0.6615988579578698',
#   'assists': '0',
#   'xA': '0.6491026850417256',
#   'shots': '5',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0.6615988579578698',
#   'xGChain': '0.9640207779593766',
#   'xGBuildup': '0.3211935800500214'},
#  {'id': '12118',
#   'player_name': 'Jamie Donley',
#   'games': '2',
#   'time': '2',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Tottenham',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12123',
#   'player_name': 'Murillo',
#   'games': '14',
#   'time': '1243',
#   'goals': '0',
#   'xG': '0.7743317726999521',
#   'assists': '1',
#   'xA': '1.0338670872151852',
#   'shots': '8',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0.7743317726999521',
#   'xGChain': '4.068312864750624',
#   'xGBuildup': '3.109786381945014'},
#  {'id': '12152',
#   'player_name': 'Matheus França',
#   'games': '5',
#   'time': '30',
#   'goals': '0',
#   'xG': '0.09937552036717534',
#   'assists': '0',
#   'xA': '0.22760880179703236',
#   'shots': '3',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Crystal Palace',
#   'npg': '0',
#   'npxG': '0.09937552036717534',
#   'xGChain': '0.27308147959411144',
#   'xGBuildup': '0.05349571630358696'},
#  {'id': '12158',
#   'player_name': 'Ryan Oné',
#   'games': '1',
#   'time': '4',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12187',
#   'player_name': 'Jordan Clark',
#   'games': '6',
#   'time': '149',
#   'goals': '0',
#   'xG': '0.1283271759748459',
#   'assists': '0',
#   'xA': '0.028225945308804512',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0.1283271759748459',
#   'xGChain': '0.35226775892078876',
#   'xGBuildup': '0.19571463763713837'},
#  {'id': '12198',
#   'player_name': 'Ben Parkinson',
#   'games': '1',
#   'time': '18',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12199',
#   'player_name': 'Alex Murphy',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12200',
#   'player_name': 'Amadou Diallo',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12204',
#   'player_name': 'Benicio Baker-Boaitey',
#   'games': '2',
#   'time': '2',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.1531512588262558',
#   'xGBuildup': '0.1531512588262558'},
#  {'id': '12215',
#   'player_name': 'Michael Ndiweni',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12251',
#   'player_name': 'Sydie Peck',
#   'games': '1',
#   'time': '6',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12275',
#   'player_name': 'Willy Kambwala',
#   'games': '2',
#   'time': '88',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Manchester United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.07591637223958969',
#   'xGBuildup': '0.07591637223958969'},
#  {'id': '12291',
#   'player_name': 'Rhys Norrington-Davies',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'}]

# %%
cols = list(e[0].keys())
vals = []

for x in e:
    vals.append(list(x.values()))

players_df = pd.DataFrame(vals, columns = cols)

# %%
players_df
# Out:
#         id             player_name games  time goals                  xG  \
# 0     1250           Mohamed Salah    20  1768    14  13.610325902700424
# 1     8260          Erling Haaland    15  1305    14  16.727499932050705
# 2      453           Son Heung-Min    20  1739    12    7.47495724260807
# 3     1679         Dominic Solanke    19  1708    12  12.378114826977253
# 4     1776            Jarrod Bowen    19  1710    11    8.29572493582964
# ..     ...                     ...   ...   ...   ...                 ...
# 500  12204   Benicio Baker-Boaitey     2     2     0                   0
# 501  12215         Michael Ndiweni     1     1     0                   0
# 502  12251              Sydie Peck     1     6     0                   0
# 503  12275          Willy Kambwala     2    88     0                   0
# 504  12291  Rhys Norrington-Davies     1     1     0                   0
#
#     assists                  xA shots key_passes yellow_cards red_cards  \
# 0         8    9.57847910746932    65         47            2         0
# 1         4  3.2472310978919268    58         16            1         0
# 2         5   6.843130592256784    52         37            1         0
# 3         1  0.9976950995624065    66         14            1         0
# 4         2   3.144163405522704    47         14            1         0
# ..      ...                 ...   ...        ...          ...       ...
# 500       0                   0     0          0            0         0
# 501       0                   0     0          0            0         0
# 502       0                   0     0          0            0         0
# 503       0                   0     0          0            0         0
# 504       0                   0     0          0            0         0
#
#     position         team_title npg               npxG              xGChain  \
# 0          F          Liverpool  10  9.043387070298195    19.68034301698208
# 1          F    Manchester City  11  13.68282476067543   16.214465029537678
# 2        F M          Tottenham  11  6.713788405060768   16.887082293629646
# 3          F        Bournemouth  11  11.61694597452879   12.262300044298172
# 4        F M           West Ham  11   8.29572493582964    9.910744827240705
# ..       ...                ...  ..                ...                  ...
# 500        S           Brighton   0                  0   0.1531512588262558
# 501        S   Newcastle United   0                  0                    0
# 502        S   Sheffield United   0                  0                    0
# 503      D S  Manchester United   0                  0  0.07591637223958969
# 504        S   Sheffield United   0                  0                    0
#
#                xGBuildup
# 0      5.720102474093437
# 1     1.3705047406256199
# 2      6.178518561646342
# 3     1.8974752612411976
# 4     1.9265567287802696
# ..                   ...
# 500   0.1531512588262558
# 501                    0
# 502                    0
# 503  0.07591637223958969
# 504                    0
#
# [505 rows x 18 columns]

# %%
async def league_table():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        table = await understat.get_league_table("EPL", "2024")
        league_table_df = pd.DataFrame(table[1:], columns = table[0])
        return league_table_df

league_table_df = asyncio.run(league_table())
league_table_df["Position"] = np.arange(1,21)

# %%
league_table_df
# Out:
#                        Team   M   W  D   L   G  GA  PTS     xG   NPxG    xGA  \
# 0                 Liverpool  20  13  6   1  43  18   45  46.31  41.46  24.88
# 1               Aston Villa  20  13  3   4  43  27   42  38.53  35.48  27.82
# 2           Manchester City  19  12  4   3  45  21   40  42.79  38.98  18.50
# 3                   Arsenal  20  12  4   4  37  20   40  40.56  35.99  19.71
# 4                 Tottenham  20  12  3   5  42  29   39  37.68  36.92  36.66
# 5                  West Ham  20  10  4   6  33  30   34  29.41  27.89  36.49
# 6                  Brighton  20   8  7   5  38  33   31  36.65  33.61  31.77
# 7         Manchester United  20  10  1   9  22  27   31  29.30  27.00  35.56
# 8          Newcastle United  20   9  2   9  39  29   29  43.62  40.58  33.92
# 9                   Chelsea  20   8  4   8  34  31   28  41.96  36.63  30.57
# 10  Wolverhampton Wanderers  20   8  4   8  30  31   28  28.56  27.79  35.79
# 11                  Everton  20   8  2  10  24  28   26  33.95  33.95  30.15
# 12              Bournemouth  19   7  4   8  28  35   25  30.59  29.83  34.12
# 13                   Fulham  20   7  3  10  28  35   24  25.87  24.35  35.81
# 14           Crystal Palace  20   5  6   9  22  29   21  27.13  24.84  31.45
# 15        Nottingham Forest  20   5  5  10  24  35   20  24.52  23.76  32.09
# 16                Brentford  19   5  4  10  26  31   19  34.77  32.49  26.27
# 17                    Luton  19   4  3  12  23  37   15  23.27  21.75  47.14
# 18                  Burnley  20   3  2  15  20  41   11  19.65  18.89  38.38
# 19         Sheffield United  20   2  3  15  15  49    9  17.31  15.79  45.34
#
#     NPxGA  NPxGD   PPDA  OPPDA   DC  ODC   xPTS  Position
# 0   24.12  17.34   8.25  16.57  242  117  38.79         1
# 1   27.82   7.66  12.59  10.36  201  128  35.42         2
# 2   16.98  22.00  11.69  21.05  220   82  40.81         3
# 3   18.19  17.80   9.10  16.76  227   91  39.24         4
# 4   32.86   4.06   8.30  10.93  270  145  29.43         5
# 5   33.44  -5.56  17.47   9.88   90  218  23.88         6
# 6   27.97   5.64   9.18  17.07  219  179  30.50         7
# 7   34.04  -7.04  11.72  13.68  178  164  23.78         8
# 8   31.51   9.06   9.97  11.72  175  129  34.59         9
# 9   28.27   8.36   8.91  14.25  207  126  34.39        10
# 10  31.98  -4.19  12.21   9.67  122  195  22.88        11
# 11  26.35   7.61  13.82   9.99  124  161  30.40        12
# 12  31.68  -1.84  10.61   8.43  154  202  25.43        13
# 13  32.01  -7.66  13.44  13.43  144  165  22.85        14
# 14  29.16  -4.32  13.35   8.53  131  175  24.80        15
# 15  29.81  -6.04  17.97  10.24  107  191  22.98        16
# 16  25.51   6.98   9.47  11.03  147  163  30.04        17
# 17  46.38 -24.63  15.23   7.06   82  193  14.62        18
# 18  36.10 -17.21  13.76  13.22   97  196  15.89        19
# 19  43.81 -28.03  15.99   8.45   83  200  12.64        20

# %%
total_shots = []
players_id = list(players_df["id"])


async def get_player_shots(player_id):
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        shots = await understat.get_player_shots(
            player_id
        )
        return json.dumps(shots)
for x in players_id:
    shots = asyncio.run(get_player_shots(x))
    shots = json.loads(shots)
    total_shots.append(shots)

# %%
def flatten_extend(matrix):
    flat_list = []
    for row in matrix:
        flat_list.extend(row)
    return flat_list

total_shots = flatten_extend(total_shots)

# %%
cols2 = list(total_shots[0].keys())
vals2 = []

for x in total_shots:
    vals2.append(list(x.values()))

total_player_shots_df = pd.DataFrame(vals2, columns = cols2)

# %%
total_player_shots_df['date']= pd.to_datetime(total_player_shots_df['date'])
total_player_shots_df = total_player_shots_df[total_player_shots_df["date"] > '2023-07-01']

# %%
total_player_shots_df
# Out:
#            id minute       result                   X                   Y  \
# 985    532588     11   ShotOnPost  0.8190000152587891  0.5279999923706055
# 986    532592     25  BlockedShot   0.850999984741211               0.445
# 987    532594     40  MissedShots  0.8590000152587891               0.315
# 988    533205     33  MissedShots  0.8190000152587891  0.5720000076293945
# 989    533207     35         Goal  0.9569999694824218  0.5259999847412109
# ...       ...    ...          ...                 ...                 ...
# 50328  554063     33  MissedShots  0.8619999694824219                 0.3
# 50329  557107     26  MissedShots   0.919000015258789  0.4490000152587891
# 50330  544109     76  MissedShots  0.6859999847412109  0.5079999923706054
# 50331  545174    101  MissedShots  0.9330000305175781  0.6270000076293946
# 50332  556621     96  BlockedShot  0.8019999694824219               0.655
#
#                           xG          player h_a player_id   situation season  \
# 985      0.06408040970563889   Mohamed Salah   a      1250    OpenPlay   2023
# 986      0.10087071359157562   Mohamed Salah   a      1250    OpenPlay   2023
# 987      0.04292548820376396   Mohamed Salah   a      1250    OpenPlay   2023
# 988      0.05514945462346077   Mohamed Salah   h      1250    OpenPlay   2023
# 989       0.6668094396591187   Mohamed Salah   h      1250    SetPiece   2023
# ...                      ...             ...  ..       ...         ...    ...
# 50328    0.04014270380139351         Murillo   h     12123    OpenPlay   2023
# 50329    0.07850664854049683         Murillo   h     12123  FromCorner   2023
# 50330  0.0074213468469679356  Matheus França   a     12152    OpenPlay   2023
# 50331     0.0706448033452034  Matheus França   h     12152    OpenPlay   2023
# 50332   0.021309370175004005  Matheus França   a     12152    OpenPlay   2023
#
#         shotType match_id             h_team             a_team h_goals  \
# 985    RightFoot    22283            Chelsea          Liverpool       1
# 986     LeftFoot    22283            Chelsea          Liverpool       1
# 987     LeftFoot    22283            Chelsea          Liverpool       1
# 988     LeftFoot    22288          Liverpool        Bournemouth       3
# 989     LeftFoot    22288          Liverpool        Bournemouth       3
# ...          ...      ...                ...                ...     ...
# 50328   LeftFoot    22063  Nottingham Forest          Tottenham       0
# 50329       Head    22091  Nottingham Forest  Manchester United       2
# 50330  RightFoot    21981   Newcastle United     Crystal Palace       4
# 50331   LeftFoot    21990     Crystal Palace          Tottenham       1
# 50332  RightFoot    22080            Chelsea     Crystal Palace       2
#
#       a_goals                date        player_assisted lastAction
# 985         1 2023-08-13 15:30:00             Cody Gakpo       Pass
# 986         1 2023-08-13 15:30:00              Luis Díaz       Pass
# 987         1 2023-08-13 15:30:00                   None       None
# 988         1 2023-08-19 14:00:00             Diogo Jota       Pass
# 989         1 2023-08-19 14:00:00                   None    Rebound
# ...       ...                 ...                    ...        ...
# 50328       2 2023-12-15 20:00:00                   None       None
# 50329       1 2023-12-30 17:30:00     Morgan Gibbs-White      Cross
# 50330       0 2023-10-21 14:00:00  Cheick Oumar Doucoure       None
# 50331       2 2023-10-27 19:00:00   Jean-Philippe Mateta   HeadPass
# 50332       1 2023-12-27 19:30:00          Michael Olise    Chipped
#
# [5323 rows x 20 columns]

# %%
async def league_results():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        fixtures = await understat.get_league_results(
            "epl",
            2024,
            {
            }
        )
        return(json.dumps(fixtures))

matches = asyncio.run(league_results())
matches = json.loads(matches)

# %%
cols3 = list(matches[0].keys())
vals3 = []

for x in matches:
    vals3.append(list(x.values()))

matches_df = pd.DataFrame(vals3, columns = cols3)

# %%
def match_parser(row):
    row["home_id"] = row["h"]["id"]
    row["away_id"] = row["a"]["id"]
    row["home_team"] = row["h"]["title"]
    row["away_team"] = row["a"]["title"]
    row["home_goals"] = row["goals"]["h"]
    row["away_goals"] = row["goals"]["a"]
    row["home_xg"] = row["xG"]["h"]
    row["away_xg"] = row["xG"]["a"]
    if row["home_goals"] == row["away_goals"]:
        row["is_draw"] = True
    else:
        row["is_draw"] = False
    if row["home_goals"] > row["away_goals"]:
        row["home_win"] = True
    else:
        row["home_win"] = False
    if row["home_goals"] < row["away_goals"]:
        row["away_win"] = True
    else:
        row["away_win"] = False
    return row

matches_df = matches_df.apply(lambda x: match_parser(x), axis=1)

# %%
matches_df
# Out:
#         id  isResult                                                  h  \
# 0    22275      True  {'id': '92', 'title': 'Burnley', 'short_title'...
# 1    22276      True  {'id': '83', 'title': 'Arsenal', 'short_title'...
# 2    22277      True  {'id': '73', 'title': 'Bournemouth', 'short_ti...
# 3    22278      True  {'id': '220', 'title': 'Brighton', 'short_titl...
# 4    22279      True  {'id': '72', 'title': 'Everton', 'short_title'...
# ..     ...       ...                                                ...
# 193  22091      True  {'id': '249', 'title': 'Nottingham Forest', 's...
# 194  22087      True  {'id': '228', 'title': 'Fulham', 'short_title'...
# 195  22092      True  {'id': '82', 'title': 'Tottenham', 'short_titl...
# 196  22088      True  {'id': '87', 'title': 'Liverpool', 'short_titl...
# 197  22093      True  {'id': '81', 'title': 'West Ham', 'short_title...
#
#                                                      a                 goals  \
# 0    {'id': '88', 'title': 'Manchester City', 'shor...  {'h': '0', 'a': '3'}
# 1    {'id': '249', 'title': 'Nottingham Forest', 's...  {'h': '2', 'a': '1'}
# 2    {'id': '81', 'title': 'West Ham', 'short_title...  {'h': '1', 'a': '1'}
# 3    {'id': '256', 'title': 'Luton', 'short_title':...  {'h': '4', 'a': '1'}
# 4    {'id': '228', 'title': 'Fulham', 'short_title'...  {'h': '0', 'a': '1'}
# ..                                                 ...                   ...
# 193  {'id': '89', 'title': 'Manchester United', 'sh...  {'h': '2', 'a': '1'}
# 194  {'id': '83', 'title': 'Arsenal', 'short_title'...  {'h': '2', 'a': '1'}
# 195  {'id': '73', 'title': 'Bournemouth', 'short_ti...  {'h': '3', 'a': '1'}
# 196  {'id': '86', 'title': 'Newcastle United', 'sho...  {'h': '4', 'a': '2'}
# 197  {'id': '220', 'title': 'Brighton', 'short_titl...  {'h': '0', 'a': '0'}
#
#                                      xG             datetime  \
# 0     {'h': '0.311032', 'a': '2.40074'}  2023-08-11 19:00:00
# 1     {'h': '0.84262', 'a': '0.966305'}  2023-08-12 11:30:00
# 2       {'h': '1.51025', 'a': '1.4834'}  2023-08-12 14:00:00
# 3      {'h': '4.36748', 'a': '1.88594'}  2023-08-12 14:00:00
# 4      {'h': '2.59001', 'a': '1.58144'}  2023-08-12 14:00:00
# ..                                  ...                  ...
# 193  {'h': '0.744348', 'a': '0.651905'}  2023-12-30 17:30:00
# 194     {'h': '1.52829', 'a': '1.6591'}  2023-12-31 14:00:00
# 195    {'h': '2.15027', 'a': '1.58229'}  2023-12-31 14:00:00
# 196   {'h': '6.67151', 'a': '0.910974'}  2024-01-01 20:00:00
# 197      {'h': '0.9831', 'a': '2.1552'}  2024-01-02 19:30:00
#
#                                           forecast home_id away_id  \
# 0    {'w': '0.0177', 'd': '0.0854', 'l': '0.8969'}      92      88
# 1     {'w': '0.2797', 'd': '0.3363', 'l': '0.384'}      83     249
# 2    {'w': '0.3559', 'd': '0.3169', 'l': '0.3272'}      73      81
# 3     {'w': '0.879', 'd': '0.0876', 'l': '0.0334'}     220     256
# 4     {'w': '0.6371', 'd': '0.1989', 'l': '0.164'}      72     228
# ..                                             ...     ...     ...
# 193  {'w': '0.3432', 'd': '0.3817', 'l': '0.2751'}     249      89
# 194   {'w': '0.3212', 'd': '0.286', 'l': '0.3928'}     228      83
# 195  {'w': '0.5177', 'd': '0.2287', 'l': '0.2536'}      82      73
# 196  {'w': '0.9981', 'd': '0.0015', 'l': '0.0004'}      87      86
# 197  {'w': '0.1215', 'd': '0.2187', 'l': '0.6598'}      81     220
#
#              home_team          away_team home_goals away_goals   home_xg  \
# 0              Burnley    Manchester City          0          3  0.311032
# 1              Arsenal  Nottingham Forest          2          1   0.84262
# 2          Bournemouth           West Ham          1          1   1.51025
# 3             Brighton              Luton          4          1   4.36748
# 4              Everton             Fulham          0          1   2.59001
# ..                 ...                ...        ...        ...       ...
# 193  Nottingham Forest  Manchester United          2          1  0.744348
# 194             Fulham            Arsenal          2          1   1.52829
# 195          Tottenham        Bournemouth          3          1   2.15027
# 196          Liverpool   Newcastle United          4          2   6.67151
# 197           West Ham           Brighton          0          0    0.9831
#
#       away_xg  is_draw  home_win  away_win
# 0     2.40074    False     False      True
# 1    0.966305    False      True     False
# 2      1.4834     True     False     False
# 3     1.88594    False      True     False
# 4     1.58144    False     False      True
# ..        ...      ...       ...       ...
# 193  0.651905    False      True     False
# 194    1.6591    False      True     False
# 195   1.58229    False      True     False
# 196  0.910974    False      True     False
# 197    2.1552     True     False     False
#
# [198 rows x 19 columns]
