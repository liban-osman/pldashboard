# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import asyncio
import json
import aiohttp
from understat import Understat
import nest_asyncio

# %%
def players():    
    nest_asyncio.apply()
    async def all_understat_players():
        async with aiohttp.ClientSession() as session:
            understat = Understat(session)
            players = await understat.get_league_players(
                "epl",
                2024,
            )
            return json.dumps(players)

    players = asyncio.run(all_understat_players())
    players = json.loads(players)
    return players

# %%
e = players()

# %%
e
# Out:
# [{'id': '1250',
#   'player_name': 'Mohamed Salah',
#   'games': '20',
#   'time': '1768',
#   'goals': '14',
#   'xG': '13.610325902700424',
#   'assists': '8',
#   'xA': '9.57847910746932',
#   'shots': '65',
#   'key_passes': '47',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Liverpool',
#   'npg': '10',
#   'npxG': '9.043387070298195',
#   'xGChain': '19.68034301698208',
#   'xGBuildup': '5.720102474093437'},
#  {'id': '8260',
#   'player_name': 'Erling Haaland',
#   'games': '15',
#   'time': '1305',
#   'goals': '14',
#   'xG': '16.727499932050705',
#   'assists': '4',
#   'xA': '3.2472310978919268',
#   'shots': '58',
#   'key_passes': '16',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Manchester City',
#   'npg': '11',
#   'npxG': '13.68282476067543',
#   'xGChain': '16.214465029537678',
#   'xGBuildup': '1.3705047406256199'},
#  {'id': '453',
#   'player_name': 'Son Heung-Min',
#   'games': '20',
#   'time': '1739',
#   'goals': '12',
#   'xG': '7.47495724260807',
#   'assists': '5',
#   'xA': '6.843130592256784',
#   'shots': '52',
#   'key_passes': '37',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Tottenham',
#   'npg': '11',
#   'npxG': '6.713788405060768',
#   'xGChain': '16.887082293629646',
#   'xGBuildup': '6.178518561646342'},
#  {'id': '1679',
#   'player_name': 'Dominic Solanke',
#   'games': '20',
#   'time': '1793',
#   'goals': '12',
#   'xG': '12.433437447994947',
#   'assists': '1',
#   'xA': '0.9976950995624065',
#   'shots': '67',
#   'key_passes': '14',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Bournemouth',
#   'npg': '11',
#   'npxG': '11.672268595546484',
#   'xGChain': '12.4195606559515',
#   'xGBuildup': '1.9994132556021214'},
#  {'id': '1776',
#   'player_name': 'Jarrod Bowen',
#   'games': '20',
#   'time': '1800',
#   'goals': '11',
#   'xG': '8.646546997129917',
#   'assists': '2',
#   'xA': '3.144163405522704',
#   'shots': '51',
#   'key_passes': '14',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'West Ham',
#   'npg': '11',
#   'npxG': '8.646546997129917',
#   'xGChain': '10.23329196497798',
#   'xGBuildup': '2.032880038022995'},
#  {'id': '5232',
#   'player_name': 'Alexander Isak',
#   'games': '16',
#   'time': '1161',
#   'goals': '10',
#   'xG': '10.588220298290253',
#   'assists': '0',
#   'xA': '1.3252181969583035',
#   'shots': '37',
#   'key_passes': '11',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '8',
#   'npxG': '9.065882563591003',
#   'xGChain': '11.43273314833641',
#   'xGBuildup': '2.939927790313959'},
#  {'id': '8845',
#   'player_name': 'Hee-Chan Hwang',
#   'games': '20',
#   'time': '1466',
#   'goals': '10',
#   'xG': '6.790349626913667',
#   'assists': '3',
#   'xA': '3.0366309229284525',
#   'shots': '35',
#   'key_passes': '14',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '9',
#   'npxG': '6.029180759564042',
#   'xGChain': '9.669545919634402',
#   'xGBuildup': '2.148992163129151'},
#  {'id': '8497',
#   'player_name': 'Cole Palmer',
#   'games': '18',
#   'time': '1235',
#   'goals': '9',
#   'xG': '7.731454914435744',
#   'assists': '4',
#   'xA': '5.087213238701224',
#   'shots': '41',
#   'key_passes': '28',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea,Manchester City',
#   'npg': '4',
#   'npxG': '3.925610648468137',
#   'xGChain': '11.595409283414483',
#   'xGBuildup': '5.120687790215015'},
#  {'id': '8865',
#   'player_name': 'Ollie Watkins',
#   'games': '21',
#   'time': '1869',
#   'goals': '9',
#   'xG': '10.780383192002773',
#   'assists': '8',
#   'xA': '4.554072014987469',
#   'shots': '61',
#   'key_passes': '31',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Aston Villa',
#   'npg': '9',
#   'npxG': '10.780383192002773',
#   'xGChain': '16.569357842206955',
#   'xGBuildup': '2.7322250166907907'},
#  {'id': '4456',
#   'player_name': 'Chris Wood',
#   'games': '19',
#   'time': '796',
#   'goals': '8',
#   'xG': '5.403706602752209',
#   'assists': '1',
#   'xA': '1.3052819389849901',
#   'shots': '21',
#   'key_passes': '16',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Nottingham Forest',
#   'npg': '8',
#   'npxG': '5.403706602752209',
#   'xGChain': '6.586503515020013',
#   'xGBuildup': '0.23899088986217976'},
#  {'id': '468',
#   'player_name': 'Callum Wilson',
#   'games': '14',
#   'time': '710',
#   'goals': '7',
#   'xG': '8.662500880658627',
#   'assists': '1',
#   'xA': '0.42866930179297924',
#   'shots': '31',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '5',
#   'npxG': '7.14016330987215',
#   'xGChain': '7.621083067730069',
#   'xGBuildup': '0.8389131352305412'},
#  {'id': '6026',
#   'player_name': 'Richarlison',
#   'games': '18',
#   'time': '1036',
#   'goals': '7',
#   'xG': '6.891492305323482',
#   'assists': '3',
#   'xA': '1.1397085152566433',
#   'shots': '41',
#   'key_passes': '10',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Tottenham',
#   'npg': '7',
#   'npxG': '6.891492305323482',
#   'xGChain': '8.663197048008442',
#   'xGBuildup': '1.551673123613'},
#  {'id': '6552',
#   'player_name': 'Bryan Mbeumo',
#   'games': '15',
#   'time': '1289',
#   'goals': '7',
#   'xG': '7.574615128338337',
#   'assists': '3',
#   'xA': '2.8948017433285713',
#   'shots': '41',
#   'key_passes': '22',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Brentford',
#   'npg': '4',
#   'npxG': '5.291108556091785',
#   'xGChain': '9.410030841827393',
#   'xGBuildup': '3.1749180927872658'},
#  {'id': '6854',
#   'player_name': 'Diogo Jota',
#   'games': '15',
#   'time': '768',
#   'goals': '7',
#   'xG': '4.165528640151024',
#   'assists': '2',
#   'xA': '1.943031596019864',
#   'shots': '26',
#   'key_passes': '16',
#   'yellow_cards': '1',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Liverpool',
#   'npg': '7',
#   'npxG': '4.165528640151024',
#   'xGChain': '8.702314913272858',
#   'xGBuildup': '5.02716045640409'},
#  {'id': '8150',
#   'player_name': 'Anthony Gordon',
#   'games': '20',
#   'time': '1705',
#   'goals': '7',
#   'xG': '6.108674101531506',
#   'assists': '5',
#   'xA': '4.997361587360501',
#   'shots': '44',
#   'key_passes': '22',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '7',
#   'npxG': '6.108674101531506',
#   'xGChain': '15.792282551527023',
#   'xGBuildup': '6.617116902023554'},
#  {'id': '8272',
#   'player_name': 'João Pedro',
#   'games': '20',
#   'time': '1120',
#   'goals': '7',
#   'xG': '6.923017270863056',
#   'assists': '2',
#   'xA': '2.871623874641955',
#   'shots': '40',
#   'key_passes': '18',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '3.8784161042422056',
#   'xGChain': '9.901699712499976',
#   'xGBuildup': '4.285971317440271'},
#  {'id': '10048',
#   'player_name': 'Nicolas Jackson',
#   'games': '19',
#   'time': '1458',
#   'goals': '7',
#   'xG': '11.180736033245921',
#   'assists': '2',
#   'xA': '2.957573415711522',
#   'shots': '45',
#   'key_passes': '16',
#   'yellow_cards': '8',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '7',
#   'npxG': '11.180736033245921',
#   'xGChain': '14.183117497712374',
#   'xGBuildup': '2.219442430883646'},
#  {'id': '10720',
#   'player_name': 'Darwin Núñez',
#   'games': '20',
#   'time': '1208',
#   'goals': '7',
#   'xG': '12.024434817023575',
#   'assists': '6',
#   'xA': '4.018361150287092',
#   'shots': '61',
#   'key_passes': '22',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Liverpool',
#   'npg': '7',
#   'npxG': '12.024434817023575',
#   'xGChain': '16.26613611727953',
#   'xGBuildup': '2.9413599893450737'},
#  {'id': '1726',
#   'player_name': 'Abdoulaye Doucouré',
#   'games': '18',
#   'time': '1550',
#   'goals': '6',
#   'xG': '7.107238318771124',
#   'assists': '0',
#   'xA': '2.105909738689661',
#   'shots': '29',
#   'key_passes': '23',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Everton',
#   'npg': '6',
#   'npxG': '7.107238318771124',
#   'xGChain': '9.587701369076967',
#   'xGBuildup': '3.7316377013921738'},
#  {'id': '3635',
#   'player_name': 'Bernardo Silva',
#   'games': '17',
#   'time': '1433',
#   'goals': '6',
#   'xG': '2.3876431211829185',
#   'assists': '4',
#   'xA': '4.979102602228522',
#   'shots': '19',
#   'key_passes': '33',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '6',
#   'npxG': '2.3876431211829185',
#   'xGChain': '14.212061738595366',
#   'xGBuildup': '8.989704987034202'},
#  {'id': '3697',
#   'player_name': 'Odsonne Edouard',
#   'games': '15',
#   'time': '1270',
#   'goals': '6',
#   'xG': '6.131767854094505',
#   'assists': '0',
#   'xA': '0.864791008643806',
#   'shots': '39',
#   'key_passes': '13',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Crystal Palace',
#   'npg': '6',
#   'npxG': '6.131767854094505',
#   'xGChain': '6.33973165974021',
#   'xGBuildup': '1.469034243375063'},
#  {'id': '5221',
#   'player_name': 'Leon Bailey',
#   'games': '19',
#   'time': '944',
#   'goals': '6',
#   'xG': '3.360622316598892',
#   'assists': '5',
#   'xA': '4.189650226384401',
#   'shots': '28',
#   'key_passes': '20',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Aston Villa',
#   'npg': '6',
#   'npxG': '3.360622316598892',
#   'xGChain': '8.962225399911404',
#   'xGBuildup': '3.049989055842161'},
#  {'id': '6122',
#   'player_name': 'Douglas Luiz',
#   'games': '20',
#   'time': '1768',
#   'goals': '6',
#   'xG': '5.334015065804124',
#   'assists': '3',
#   'xA': '2.700583701953292',
#   'shots': '37',
#   'key_passes': '29',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Aston Villa',
#   'npg': '2',
#   'npxG': '2.2893397081643343',
#   'xGChain': '10.301636811345816',
#   'xGBuildup': '8.074191553518176'},
#  {'id': '7080',
#   'player_name': 'Matheus Cunha',
#   'games': '20',
#   'time': '1718',
#   'goals': '6',
#   'xG': '5.866328570060432',
#   'assists': '5',
#   'xA': '3.1632621362805367',
#   'shots': '47',
#   'key_passes': '21',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '6',
#   'npxG': '5.866328570060432',
#   'xGChain': '8.991567961871624',
#   'xGBuildup': '1.5023581953719258'},
#  {'id': '7322',
#   'player_name': 'Bukayo Saka',
#   'games': '20',
#   'time': '1772',
#   'goals': '6',
#   'xG': '7.9882912412285805',
#   'assists': '6',
#   'xA': '7.137492910027504',
#   'shots': '51',
#   'key_passes': '52',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Arsenal',
#   'npg': '4',
#   'npxG': '6.46595361828804',
#   'xGChain': '17.194374471902847',
#   'xGBuildup': '7.623949076980352'},
#  {'id': '10177',
#   'player_name': 'Evan Ferguson',
#   'games': '18',
#   'time': '977',
#   'goals': '6',
#   'xG': '3.116366809234023',
#   'assists': '0',
#   'xA': '0.6063905879855156',
#   'shots': '26',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brighton',
#   'npg': '6',
#   'npxG': '3.116366809234023',
#   'xGChain': '5.664436191320419',
#   'xGBuildup': '2.0616533048450947'},
#  {'id': '10846',
#   'player_name': 'Julián Álvarez',
#   'games': '20',
#   'time': '1711',
#   'goals': '6',
#   'xG': '7.483333542943001',
#   'assists': '5',
#   'xA': '4.240109716542065',
#   'shots': '56',
#   'key_passes': '47',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Manchester City',
#   'npg': '5',
#   'npxG': '6.722164645791054',
#   'xGChain': '16.289245061576366',
#   'xGBuildup': '8.531317099928856'},
#  {'id': '12027',
#   'player_name': 'Mohammed Kudus',
#   'games': '16',
#   'time': '960',
#   'goals': '6',
#   'xG': '1.8171145021915436',
#   'assists': '1',
#   'xA': '1.3321975693106651',
#   'shots': '21',
#   'key_passes': '11',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'West Ham',
#   'npg': '6',
#   'npxG': '1.8171145021915436',
#   'xGChain': '4.752290626987815',
#   'xGBuildup': '2.4629297740757465'},
#  {'id': '618',
#   'player_name': 'Raheem Sterling',
#   'games': '19',
#   'time': '1523',
#   'goals': '5',
#   'xG': '5.865220725536346',
#   'assists': '3',
#   'xA': '3.692453084513545',
#   'shots': '34',
#   'key_passes': '22',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '5',
#   'npxG': '5.865220725536346',
#   'xGChain': '13.737415539100766',
#   'xGBuildup': '5.922000112012029'},
#  {'id': '4105',
#   'player_name': 'Raúl Jiménez',
#   'games': '18',
#   'time': '1237',
#   'goals': '5',
#   'xG': '4.338343150913715',
#   'assists': '0',
#   'xA': '1.4086075089871883',
#   'shots': '34',
#   'key_passes': '9',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Fulham',
#   'npg': '5',
#   'npxG': '4.338343150913715',
#   'xGChain': '5.841095481067896',
#   'xGBuildup': '1.3985759727656841'},
#  {'id': '5560',
#   'player_name': 'Scott McTominay',
#   'games': '18',
#   'time': '1138',
#   'goals': '5',
#   'xG': '4.572265377268195',
#   'assists': '0',
#   'xA': '0.4636244382709265',
#   'shots': '30',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester United',
#   'npg': '5',
#   'npxG': '4.572265377268195',
#   'xGChain': '5.256055859848857',
#   'xGBuildup': '1.3749198503792286'},
#  {'id': '6055',
#   'player_name': 'Phil Foden',
#   'games': '20',
#   'time': '1611',
#   'goals': '5',
#   'xG': '5.005221089348197',
#   'assists': '6',
#   'xA': '5.096725314855576',
#   'shots': '49',
#   'key_passes': '42',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester City',
#   'npg': '5',
#   'npxG': '5.005221089348197',
#   'xGChain': '15.203431889414787',
#   'xGBuildup': '9.089750515297055'},
#  {'id': '6482',
#   'player_name': 'Eddie Nketiah',
#   'games': '20',
#   'time': '961',
#   'goals': '5',
#   'xG': '4.617060862481594',
#   'assists': '2',
#   'xA': '1.1168143339455128',
#   'shots': '32',
#   'key_passes': '8',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal',
#   'npg': '5',
#   'npxG': '4.617060862481594',
#   'xGChain': '5.298551928251982',
#   'xGBuildup': '0.9136706292629242'},
#  {'id': '6691',
#   'player_name': 'Dejan Kulusevski',
#   'games': '19',
#   'time': '1693',
#   'goals': '5',
#   'xG': '2.9024968929588795',
#   'assists': '2',
#   'xA': '5.030836449936032',
#   'shots': '34',
#   'key_passes': '42',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Tottenham',
#   'npg': '5',
#   'npxG': '2.9024968929588795',
#   'xGChain': '13.003110483288765',
#   'xGBuildup': '7.025578789412975'},
#  {'id': '7723',
#   'player_name': 'John McGinn',
#   'games': '21',
#   'time': '1832',
#   'goals': '5',
#   'xG': '3.025155894458294',
#   'assists': '2',
#   'xA': '3.662117499858141',
#   'shots': '27',
#   'key_passes': '30',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Aston Villa',
#   'npg': '5',
#   'npxG': '3.025155894458294',
#   'xGChain': '13.772848129272461',
#   'xGBuildup': '8.77267088368535'},
#  {'id': '8288',
#   'player_name': 'Tomas Soucek',
#   'games': '20',
#   'time': '1624',
#   'goals': '5',
#   'xG': '5.97108955308795',
#   'assists': '1',
#   'xA': '0.9749790970236063',
#   'shots': '25',
#   'key_passes': '7',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'West Ham',
#   'npg': '5',
#   'npxG': '5.97108955308795',
#   'xGChain': '8.03672768175602',
#   'xGBuildup': '3.5058325389400125'},
#  {'id': '9948',
#   'player_name': 'Michael Olise',
#   'games': '9',
#   'time': '665',
#   'goals': '5',
#   'xG': '2.9752268474549055',
#   'assists': '1',
#   'xA': '2.2578294202685356',
#   'shots': '26',
#   'key_passes': '19',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Crystal Palace',
#   'npg': '4',
#   'npxG': '2.2140579763799906',
#   'xGChain': '4.5320023614913225',
#   'xGBuildup': '2.2123710457235575'},
#  {'id': '11718',
#   'player_name': 'Elijah Adebayo',
#   'games': '20',
#   'time': '900',
#   'goals': '5',
#   'xG': '3.6024141926318407',
#   'assists': '0',
#   'xA': '0.7467418294399977',
#   'shots': '18',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Luton',
#   'npg': '5',
#   'npxG': '3.6024141926318407',
#   'xGChain': '4.79135718382895',
#   'xGBuildup': '0.8263525683432817'},
#  {'id': '556',
#   'player_name': 'Marcus Rashford',
#   'games': '20',
#   'time': '1424',
#   'goals': '4',
#   'xG': '5.52735791541636',
#   'assists': '2',
#   'xA': '1.9994493909180164',
#   'shots': '44',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester United',
#   'npg': '3',
#   'npxG': '4.766189077869058',
#   'xGChain': '9.01898537017405',
#   'xGBuildup': '2.8997791819274426'},
#  {'id': '700',
#   'player_name': 'Willian',
#   'games': '17',
#   'time': '1181',
#   'goals': '4',
#   'xG': '3.8347914731130004',
#   'assists': '1',
#   'xA': '1.7466816352680326',
#   'shots': '28',
#   'key_passes': '24',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Fulham',
#   'npg': '2',
#   'npxG': '2.312453798018396',
#   'xGChain': '8.445149272680283',
#   'xGBuildup': '5.642697710543871'},
#  {'id': '843',
#   'player_name': 'James Ward-Prowse',
#   'games': '20',
#   'time': '1788',
#   'goals': '4',
#   'xG': '3.7420493504032493',
#   'assists': '6',
#   'xA': '4.477268010377884',
#   'shots': '25',
#   'key_passes': '40',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'West Ham',
#   'npg': '3',
#   'npxG': '2.980880512855947',
#   'xGChain': '8.452887444756925',
#   'xGBuildup': '5.532460195943713'},
#  {'id': '1299',
#   'player_name': 'Mario Lemina',
#   'games': '17',
#   'time': '1492',
#   'goals': '4',
#   'xG': '3.0691163102164865',
#   'assists': '0',
#   'xA': '0.2353523187339306',
#   'shots': '26',
#   'key_passes': '4',
#   'yellow_cards': '7',
#   'red_cards': '1',
#   'position': 'M',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '4',
#   'npxG': '3.0691163102164865',
#   'xGChain': '4.000854138284922',
#   'xGBuildup': '2.9168977215886116'},
#  {'id': '1736',
#   'player_name': 'Oliver McBurnie',
#   'games': '12',
#   'time': '719',
#   'goals': '4',
#   'xG': '4.185765039175749',
#   'assists': '1',
#   'xA': '1.44778685644269',
#   'shots': '19',
#   'key_passes': '6',
#   'yellow_cards': '1',
#   'red_cards': '2',
#   'position': 'F S',
#   'team_title': 'Sheffield United',
#   'npg': '2',
#   'npxG': '2.6634272895753384',
#   'xGChain': '3.6648588282987475',
#   'xGBuildup': '1.2522973036393523'},
#  {'id': '2496',
#   'player_name': 'Rodri',
#   'games': '17',
#   'time': '1469',
#   'goals': '4',
#   'xG': '2.966092085465789',
#   'assists': '3',
#   'xA': '2.40580415353179',
#   'shots': '37',
#   'key_passes': '20',
#   'yellow_cards': '7',
#   'red_cards': '1',
#   'position': 'M',
#   'team_title': 'Manchester City',
#   'npg': '4',
#   'npxG': '2.966092085465789',
#   'xGChain': '15.092251479625702',
#   'xGBuildup': '12.360695481300354'},
#  {'id': '2517',
#   'player_name': 'Martin Odegaard',
#   'games': '18',
#   'time': '1606',
#   'goals': '4',
#   'xG': '3.585976341739297',
#   'assists': '3',
#   'xA': '4.750439763069153',
#   'shots': '40',
#   'key_passes': '47',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Arsenal',
#   'npg': '2',
#   'npxG': '2.0636754538863897',
#   'xGChain': '13.171133548021317',
#   'xGBuildup': '9.095927521586418'},
#  {'id': '5220',
#   'player_name': 'Kai Havertz',
#   'games': '20',
#   'time': '1245',
#   'goals': '4',
#   'xG': '4.183988839387894',
#   'assists': '1',
#   'xA': '1.2460595481097698',
#   'shots': '25',
#   'key_passes': '16',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '3.422820009291172',
#   'xGChain': '9.2761754617095',
#   'xGBuildup': '5.428735477849841'},
#  {'id': '5786',
#   'player_name': 'Yoane Wissa',
#   'games': '19',
#   'time': '1588',
#   'goals': '4',
#   'xG': '6.614129316061735',
#   'assists': '1',
#   'xA': '1.7804004363715649',
#   'shots': '43',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brentford',
#   'npg': '4',
#   'npxG': '6.614129316061735',
#   'xGChain': '8.974249444901943',
#   'xGBuildup': '2.4045274388045073'},
#  {'id': '6556',
#   'player_name': 'Moussa Diaby',
#   'games': '21',
#   'time': '1407',
#   'goals': '4',
#   'xG': '4.0835673697292805',
#   'assists': '4',
#   'xA': '5.309569384902716',
#   'shots': '36',
#   'key_passes': '29',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Aston Villa',
#   'npg': '4',
#   'npxG': '4.0835673697292805',
#   'xGChain': '11.838155675679445',
#   'xGBuildup': '5.104756154119968'},
#  {'id': '6827',
#   'player_name': 'Bobby Reid',
#   'games': '19',
#   'time': '871',
#   'goals': '4',
#   'xG': '3.803046409972012',
#   'assists': '0',
#   'xA': '0.41242159344255924',
#   'shots': '18',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Fulham',
#   'npg': '4',
#   'npxG': '3.803046409972012',
#   'xGChain': '3.6716624395921826',
#   'xGBuildup': '1.215634698048234'},
#  {'id': '7498',
#   'player_name': 'Lyle Foster',
#   'games': '12',
#   'time': '994',
#   'goals': '4',
#   'xG': '2.4960236698389053',
#   'assists': '3',
#   'xA': '0.9377795774489641',
#   'shots': '18',
#   'key_passes': '10',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Burnley',
#   'npg': '4',
#   'npxG': '2.4960236698389053',
#   'xGChain': '3.658179145306349',
#   'xGBuildup': '0.9448364581912756'},
#  {'id': '7698',
#   'player_name': 'Leandro Trossard',
#   'games': '17',
#   'time': '713',
#   'goals': '4',
#   'xG': '5.1758448369801044',
#   'assists': '1',
#   'xA': '2.0012934990227222',
#   'shots': '28',
#   'key_passes': '13',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Arsenal',
#   'npg': '4',
#   'npxG': '5.1758448369801044',
#   'xGChain': '8.059528907760978',
#   'xGBuildup': '1.9624435752630234'},
#  {'id': '7752',
#   'player_name': 'Gabriel Martinelli',
#   'games': '19',
#   'time': '1359',
#   'goals': '4',
#   'xG': '4.07419765740633',
#   'assists': '2',
#   'xA': '2.0778841953724623',
#   'shots': '35',
#   'key_passes': '28',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal',
#   'npg': '4',
#   'npxG': '4.07419765740633',
#   'xGChain': '9.310565210878849',
#   'xGBuildup': '4.591544988565147'},
#  {'id': '7814',
#   'player_name': 'Taiwo Awoniyi',
#   'games': '10',
#   'time': '688',
#   'goals': '4',
#   'xG': '3.715350016951561',
#   'assists': '2',
#   'xA': '0.6755558587610722',
#   'shots': '12',
#   'key_passes': '9',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Nottingham Forest',
#   'npg': '4',
#   'npxG': '3.715350016951561',
#   'xGChain': '4.271361701190472',
#   'xGBuildup': '1.0210123481228948'},
#  {'id': '9524',
#   'player_name': 'Anthony Elanga',
#   'games': '20',
#   'time': '1353',
#   'goals': '4',
#   'xG': '3.1140028964728117',
#   'assists': '6',
#   'xA': '4.6477286368608475',
#   'shots': '35',
#   'key_passes': '19',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '4',
#   'npxG': '3.1140028964728117',
#   'xGChain': '9.760287281125784',
#   'xGBuildup': '2.8164664208889008'},
#  {'id': '11701',
#   'player_name': 'Zeki Amdouni',
#   'games': '20',
#   'time': '1531',
#   'goals': '4',
#   'xG': '3.9232411235570908',
#   'assists': '1',
#   'xA': '1.178643874824047',
#   'shots': '33',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Burnley',
#   'npg': '4',
#   'npxG': '3.9232411235570908',
#   'xGChain': '5.937796823680401',
#   'xGBuildup': '2.276346266269684'},
#  {'id': '11710',
#   'player_name': 'Simon Adingra',
#   'games': '17',
#   'time': '1155',
#   'goals': '4',
#   'xG': '2.9683602191507816',
#   'assists': '1',
#   'xA': '1.7514075338840485',
#   'shots': '20',
#   'key_passes': '18',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Brighton',
#   'npg': '4',
#   'npxG': '2.9683602191507816',
#   'xGChain': '6.599735658615828',
#   'xGBuildup': '2.573754632845521'},
#  {'id': '11717',
#   'player_name': 'Carlton Morris',
#   'games': '20',
#   'time': '1268',
#   'goals': '4',
#   'xG': '5.101757202297449',
#   'assists': '2',
#   'xA': '0.9384258855134249',
#   'shots': '35',
#   'key_passes': '9',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Luton',
#   'npg': '2',
#   'npxG': '3.5794194675982',
#   'xGChain': '6.234991744160652',
#   'xGBuildup': '3.564909912645817'},
#  {'id': '239',
#   'player_name': 'Pascal Groß',
#   'games': '18',
#   'time': '1550',
#   'goals': '3',
#   'xG': '3.2966111712157726',
#   'assists': '6',
#   'xA': '4.212384800426662',
#   'shots': '35',
#   'key_passes': '50',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '3.2966111712157726',
#   'xGChain': '12.585024908185005',
#   'xGBuildup': '9.521034626290202'},
#  {'id': '500',
#   'player_name': 'Alex Iwobi',
#   'games': '18',
#   'time': '1302',
#   'goals': '3',
#   'xG': '3.7226694729179144',
#   'assists': '1',
#   'xA': '1.4090919205918908',
#   'shots': '36',
#   'key_passes': '20',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Everton,Fulham',
#   'npg': '3',
#   'npxG': '3.7226694729179144',
#   'xGChain': '8.697275310754776',
#   'xGBuildup': '5.117713296785951'},
#  {'id': '675',
#   'player_name': 'Jack Grealish',
#   'games': '12',
#   'time': '672',
#   'goals': '3',
#   'xG': '2.0509971976280212',
#   'assists': '1',
#   'xA': '2.3464410826563835',
#   'shots': '16',
#   'key_passes': '19',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '3',
#   'npxG': '2.0509971976280212',
#   'xGChain': '7.660753205418587',
#   'xGBuildup': '4.201451004482806'},
#  {'id': '1228',
#   'player_name': 'Bruno Fernandes',
#   'games': '20',
#   'time': '1800',
#   'goals': '3',
#   'xG': '4.925905498676002',
#   'assists': '3',
#   'xA': '6.675072144716978',
#   'shots': '49',
#   'key_passes': '55',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Manchester United',
#   'npg': '2',
#   'npxG': '3.4035677341744304',
#   'xGChain': '11.353011839091778',
#   'xGBuildup': '6.503958262503147'},
#  {'id': '3621',
#   'player_name': 'Neal Maupay',
#   'games': '17',
#   'time': '844',
#   'goals': '3',
#   'xG': '5.412918847054243',
#   'assists': '3',
#   'xA': '1.4316930631175637',
#   'shots': '31',
#   'key_passes': '10',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brentford,Everton',
#   'npg': '3',
#   'npxG': '5.412918847054243',
#   'xGChain': '8.31853761896491',
#   'xGBuildup': '2.0382075533270836'},
#  {'id': '5543',
#   'player_name': 'Gabriel Jesus',
#   'games': '16',
#   'time': '1041',
#   'goals': '3',
#   'xG': '5.295416668057442',
#   'assists': '2',
#   'xA': '2.6471346132457256',
#   'shots': '35',
#   'key_passes': '20',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '5.295416668057442',
#   'xGChain': '10.943056378513575',
#   'xGBuildup': '3.933274481445551'},
#  {'id': '5553',
#   'player_name': 'Declan Rice',
#   'games': '21',
#   'time': '1833',
#   'goals': '3',
#   'xG': '1.1911354875192046',
#   'assists': '2',
#   'xA': '1.9911468494683504',
#   'shots': '28',
#   'key_passes': '16',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '1.1911354875192046',
#   'xGChain': '10.177794649265707',
#   'xGBuildup': '8.934643633663654'},
#  {'id': '5555',
#   'player_name': 'Dominic Calvert-Lewin',
#   'games': '17',
#   'time': '1174',
#   'goals': '3',
#   'xG': '7.5956565625965595',
#   'assists': '0',
#   'xA': '0.7324996585957706',
#   'shots': '34',
#   'key_passes': '10',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Everton',
#   'npg': '3',
#   'npxG': '7.5956565625965595',
#   'xGChain': '6.966042343527079',
#   'xGBuildup': '0.6413102764636278'},
#  {'id': '6049',
#   'player_name': 'Solly March',
#   'games': '7',
#   'time': '571',
#   'goals': '3',
#   'xG': '2.7198847085237503',
#   'assists': '1',
#   'xA': '0.9913322664797306',
#   'shots': '14',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '2.7198847085237503',
#   'xGChain': '4.9072911739349365',
#   'xGBuildup': '2.40057972073555'},
#  {'id': '6818',
#   'player_name': 'James Maddison',
#   'games': '11',
#   'time': '909',
#   'goals': '3',
#   'xG': '2.944616189226508',
#   'assists': '5',
#   'xA': '3.4641558043658733',
#   'shots': '27',
#   'key_passes': '31',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Tottenham',
#   'npg': '3',
#   'npxG': '2.944616189226508',
#   'xGChain': '9.78583274781704',
#   'xGBuildup': '5.331316661089659'},
#  {'id': '7166',
#   'player_name': 'Mathias Jensen',
#   'games': '15',
#   'time': '1127',
#   'goals': '3',
#   'xG': '0.5083783445879817',
#   'assists': '3',
#   'xA': '3.1156569235026836',
#   'shots': '9',
#   'key_passes': '22',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Brentford',
#   'npg': '3',
#   'npxG': '0.5083783445879817',
#   'xGChain': '6.195955510251224',
#   'xGBuildup': '5.482214672490954'},
#  {'id': '7218',
#   'player_name': 'Cristian Romero',
#   'games': '16',
#   'time': '1266',
#   'goals': '3',
#   'xG': '1.4355695582926273',
#   'assists': '0',
#   'xA': '0.23308596201241016',
#   'shots': '11',
#   'key_passes': '5',
#   'yellow_cards': '4',
#   'red_cards': '1',
#   'position': 'D',
#   'team_title': 'Tottenham',
#   'npg': '3',
#   'npxG': '1.4355695582926273',
#   'xGChain': '10.041514728218317',
#   'xGBuildup': '9.977142874151468'},
#  {'id': '7420',
#   'player_name': 'Miguel Almirón',
#   'games': '21',
#   'time': '1462',
#   'goals': '3',
#   'xG': '4.312681986019015',
#   'assists': '1',
#   'xA': '1.8104861080646515',
#   'shots': '34',
#   'key_passes': '19',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '3',
#   'npxG': '4.312681986019015',
#   'xGChain': '9.506275802850723',
#   'xGBuildup': '4.202272681519389'},
#  {'id': '8323',
#   'player_name': 'Josh Brownhill',
#   'games': '20',
#   'time': '1588',
#   'goals': '3',
#   'xG': '0.8141022082418203',
#   'assists': '0',
#   'xA': '0.7887266166508198',
#   'shots': '18',
#   'key_passes': '17',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Burnley',
#   'npg': '3',
#   'npxG': '0.8141022082418203',
#   'xGChain': '3.273689813911915',
#   'xGBuildup': '2.4721789341419935'},
#  {'id': '8706',
#   'player_name': 'Eberechi Eze',
#   'games': '15',
#   'time': '1090',
#   'goals': '3',
#   'xG': '4.599045142531395',
#   'assists': '1',
#   'xA': '2.879009835422039',
#   'shots': '44',
#   'key_passes': '31',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '3.837876297533512',
#   'xGChain': '6.722890444099903',
#   'xGBuildup': '2.764115057885647'},
#  {'id': '9912',
#   'player_name': 'Cameron Archer',
#   'games': '19',
#   'time': '1361',
#   'goals': '3',
#   'xG': '3.028687410056591',
#   'assists': '0',
#   'xA': '2.0871694944798946',
#   'shots': '25',
#   'key_passes': '18',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Aston Villa,Sheffield United',
#   'npg': '3',
#   'npxG': '3.028687410056591',
#   'xGChain': '5.71785010304302',
#   'xGBuildup': '0.6516845105215907'},
#  {'id': '10408',
#   'player_name': 'Luis Díaz',
#   'games': '20',
#   'time': '1257',
#   'goals': '3',
#   'xG': '3.8557208348065615',
#   'assists': '1',
#   'xA': '2.0027750954031944',
#   'shots': '36',
#   'key_passes': '22',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Liverpool',
#   'npg': '3',
#   'npxG': '3.8557208348065615',
#   'xGChain': '8.70183439180255',
#   'xGBuildup': '4.622670624405146'},
#  {'id': '10552',
#   'player_name': 'Alejandro Garnacho',
#   'games': '19',
#   'time': '1156',
#   'goals': '3',
#   'xG': '3.6620294004678726',
#   'assists': '2',
#   'xA': '2.0879225991666317',
#   'shots': '43',
#   'key_passes': '20',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester United',
#   'npg': '3',
#   'npxG': '3.6620294004678726',
#   'xGChain': '7.316430777311325',
#   'xGBuildup': '2.0512901544570923'},
#  {'id': '10806',
#   'player_name': 'Kaoru Mitoma',
#   'games': '17',
#   'time': '1308',
#   'goals': '3',
#   'xG': '4.136269833892584',
#   'assists': '4',
#   'xA': '2.9180683754384518',
#   'shots': '31',
#   'key_passes': '23',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '4.136269833892584',
#   'xGChain': '12.729066520929337',
#   'xGBuildup': '7.843828905373812'},
#  {'id': '10822',
#   'player_name': 'Wilson Odobert',
#   'games': '12',
#   'time': '677',
#   'goals': '3',
#   'xG': '0.8061727080494165',
#   'assists': '1',
#   'xA': '1.4515807460993528',
#   'shots': '15',
#   'key_passes': '11',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Burnley',
#   'npg': '3',
#   'npxG': '0.8061727080494165',
#   'xGChain': '2.765665901824832',
#   'xGBuildup': '0.827910590916872'},
#  {'id': '11296',
#   'player_name': 'Cody Gakpo',
#   'games': '19',
#   'time': '839',
#   'goals': '3',
#   'xG': '3.9826766587793827',
#   'assists': '2',
#   'xA': '0.6647273600101471',
#   'shots': '26',
#   'key_passes': '11',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Liverpool',
#   'npg': '3',
#   'npxG': '3.9826766587793827',
#   'xGChain': '6.701387565582991',
#   'xGBuildup': '3.100785266608'},
#  {'id': '11305',
#   'player_name': 'Mykhailo Mudryk',
#   'games': '17',
#   'time': '787',
#   'goals': '3',
#   'xG': '2.2611535973846912',
#   'assists': '1',
#   'xA': '1.4049776643514633',
#   'shots': '15',
#   'key_passes': '14',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '3',
#   'npxG': '2.2611535973846912',
#   'xGChain': '4.177526333369315',
#   'xGBuildup': '1.2654564678668976'},
#  {'id': '11363',
#   'player_name': 'Antoine Semenyo',
#   'games': '16',
#   'time': '882',
#   'goals': '3',
#   'xG': '2.4580556955188513',
#   'assists': '1',
#   'xA': '1.8391491137444973',
#   'shots': '33',
#   'key_passes': '11',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Bournemouth',
#   'npg': '3',
#   'npxG': '2.4580556955188513',
#   'xGChain': '6.136833339929581',
#   'xGBuildup': '1.9559768363833427'},
#  {'id': '87',
#   'player_name': 'Joelinton',
#   'games': '16',
#   'time': '1154',
#   'goals': '2',
#   'xG': '2.0550636127591133',
#   'assists': '1',
#   'xA': '1.9260431751608849',
#   'shots': '15',
#   'key_passes': '18',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '2.0550636127591133',
#   'xGChain': '7.462845517322421',
#   'xGBuildup': '4.510361844673753'},
#  {'id': '501',
#   'player_name': 'Danny Welbeck',
#   'games': '12',
#   'time': '619',
#   'goals': '2',
#   'xG': '1.8282979186624289',
#   'assists': '0',
#   'xA': '0.706577192991972',
#   'shots': '15',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Brighton',
#   'npg': '2',
#   'npxG': '1.8282979186624289',
#   'xGChain': '5.324061509221792',
#   'xGBuildup': '3.7471321634948254'},
#  {'id': '531',
#   'player_name': 'Michail Antonio',
#   'games': '12',
#   'time': '859',
#   'goals': '2',
#   'xG': '1.9163854327052832',
#   'assists': '2',
#   'xA': '0.9527668282389641',
#   'shots': '9',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'West Ham',
#   'npg': '2',
#   'npxG': '1.9163854327052832',
#   'xGChain': '5.270372709259391',
#   'xGBuildup': '2.401220466941595'},
#  {'id': '579',
#   'player_name': 'Nathan Aké',
#   'games': '16',
#   'time': '1098',
#   'goals': '2',
#   'xG': '1.3204994723200798',
#   'assists': '1',
#   'xA': '1.568371705710888',
#   'shots': '15',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '1.3204994723200798',
#   'xGChain': '6.5931935384869576',
#   'xGBuildup': '5.554286040365696'},
#  {'id': '592',
#   'player_name': 'Ross Barkley',
#   'games': '15',
#   'time': '1162',
#   'goals': '2',
#   'xG': '1.5443060453981161',
#   'assists': '1',
#   'xA': '2.1783274598419666',
#   'shots': '35',
#   'key_passes': '17',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Luton',
#   'npg': '2',
#   'npxG': '1.5443060453981161',
#   'xGChain': '4.6657176874578',
#   'xGBuildup': '3.0914752949029207'},
#  {'id': '672',
#   'player_name': 'Jordan Ayew',
#   'games': '19',
#   'time': '1557',
#   'goals': '2',
#   'xG': '3.114279456436634',
#   'assists': '5',
#   'xA': '3.983744007535279',
#   'shots': '31',
#   'key_passes': '16',
#   'yellow_cards': '4',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '3.114279456436634',
#   'xGChain': '7.141842287033796',
#   'xGBuildup': '3.52212190721184'},
#  {'id': '844',
#   'player_name': 'Jay Rodriguez',
#   'games': '13',
#   'time': '690',
#   'goals': '2',
#   'xG': '3.9125491455197334',
#   'assists': '1',
#   'xA': '0.14750910177826881',
#   'shots': '18',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Burnley',
#   'npg': '1',
#   'npxG': '3.151380307972431',
#   'xGChain': '3.697810996323824',
#   'xGBuildup': '0.654015134088695'},
#  {'id': '1654',
#   'player_name': 'Ben Mee',
#   'games': '10',
#   'time': '776',
#   'goals': '2',
#   'xG': '0.8827042728662491',
#   'assists': '0',
#   'xA': '0.24989730305969715',
#   'shots': '8',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'D S',
#   'team_title': 'Brentford',
#   'npg': '2',
#   'npxG': '0.8827042728662491',
#   'xGChain': '1.5633754208683968',
#   'xGBuildup': '1.160984767600894'},
#  {'id': '1791',
#   'player_name': 'Trent Alexander-Arnold',
#   'games': '18',
#   'time': '1508',
#   'goals': '2',
#   'xG': '1.8993023708462715',
#   'assists': '3',
#   'xA': '5.973722470924258',
#   'shots': '29',
#   'key_passes': '49',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Liverpool',
#   'npg': '2',
#   'npxG': '1.8993023708462715',
#   'xGChain': '11.573892042040825',
#   'xGBuildup': '8.901589676737785'},
#  {'id': '5136',
#   'player_name': 'Estupiñán',
#   'games': '8',
#   'time': '630',
#   'goals': '2',
#   'xG': '0.9772415244951844',
#   'assists': '3',
#   'xA': '2.6487050093710423',
#   'shots': '9',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Brighton',
#   'npg': '2',
#   'npxG': '0.9772415244951844',
#   'xGChain': '6.447533935308456',
#   'xGBuildup': '4.532369887456298'},
#  {'id': '5355',
#   'player_name': 'Jacob Bruun Larsen',
#   'games': '17',
#   'time': '437',
#   'goals': '2',
#   'xG': '1.0551242250949144',
#   'assists': '0',
#   'xA': '0.5736029893159866',
#   'shots': '15',
#   'key_passes': '11',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Burnley',
#   'npg': '2',
#   'npxG': '1.0551242250949144',
#   'xGChain': '1.5870495131239295',
#   'xGBuildup': '0.5289615169167519'},
#  {'id': '5596',
#   'player_name': 'Harry Wilson',
#   'games': '21',
#   'time': '1087',
#   'goals': '2',
#   'xG': '1.4659033138304949',
#   'assists': '3',
#   'xA': '1.9476792868226767',
#   'shots': '23',
#   'key_passes': '12',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Fulham',
#   'npg': '2',
#   'npxG': '1.4659033138304949',
#   'xGChain': '4.559948775917292',
#   'xGBuildup': '2.769687367603183'},
#  {'id': '5613',
#   'player_name': 'Gabriel',
#   'games': '19',
#   'time': '1544',
#   'goals': '2',
#   'xG': '1.903535034507513',
#   'assists': '0',
#   'xA': '0.8747859355062246',
#   'shots': '15',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Arsenal',
#   'npg': '2',
#   'npxG': '1.903535034507513',
#   'xGChain': '6.449009439907968',
#   'xGBuildup': '5.579258100129664'},
#  {'id': '5681',
#   'player_name': 'Giovani Lo Celso',
#   'games': '10',
#   'time': '403',
#   'goals': '2',
#   'xG': '0.36788101494312286',
#   'assists': '2',
#   'xA': '0.6810179241001606',
#   'shots': '8',
#   'key_passes': '11',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Tottenham',
#   'npg': '2',
#   'npxG': '0.36788101494312286',
#   'xGChain': '2.3931398577988148',
#   'xGBuildup': '1.6784910075366497'},
#  {'id': '5735',
#   'player_name': 'Jean-Philippe Mateta',
#   'games': '18',
#   'time': '873',
#   'goals': '2',
#   'xG': '2.5698488652706146',
#   'assists': '3',
#   'xA': '2.2754142582416534',
#   'shots': '13',
#   'key_passes': '18',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Crystal Palace',
#   'npg': '1',
#   'npxG': '1.8086800053715706',
#   'xGChain': '4.353659592568874',
#   'xGBuildup': '0.6946454010903835'},
#  {'id': '6034',
#   'player_name': 'Philip Billing',
#   'games': '19',
#   'time': '1165',
#   'goals': '2',
#   'xG': '2.4570786003023386',
#   'assists': '2',
#   'xA': '2.362320439890027',
#   'shots': '23',
#   'key_passes': '18',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Bournemouth',
#   'npg': '2',
#   'npxG': '2.4570786003023386',
#   'xGChain': '5.851955099031329',
#   'xGBuildup': '2.5573682244867086'},
#  {'id': '6221',
#   'player_name': 'Pau Torres',
#   'games': '18',
#   'time': '1515',
#   'goals': '2',
#   'xG': '1.419058132916689',
#   'assists': '0',
#   'xA': '0.593196582980454',
#   'shots': '9',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Aston Villa',
#   'npg': '2',
#   'npxG': '1.419058132916689',
#   'xGChain': '7.397438765503466',
#   'xGBuildup': '7.1878891522064805'},
#  {'id': '6314',
#   'player_name': 'Joachim Andersen',
#   'games': '21',
#   'time': '1890',
#   'goals': '2',
#   'xG': '1.7460184623487294',
#   'assists': '1',
#   'xA': '1.3842538334429264',
#   'shots': '16',
#   'key_passes': '13',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '1.7460184623487294',
#   'xGChain': '6.324732141569257',
#   'xGBuildup': '5.916726833209395'},
#  {'id': '6490',
#   'player_name': 'Manuel Akanji',
#   'games': '15',
#   'time': '1261',
#   'goals': '2',
#   'xG': '0.7294066920876503',
#   'assists': '0',
#   'xA': '0.20319249480962753',
#   'shots': '7',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'D M S',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '0.7294066920876503',
#   'xGChain': '6.64615198969841',
#   'xGBuildup': '6.564498256891966'},
#  {'id': '6756',
#   'player_name': 'Dwight McNeil',
#   'games': '18',
#   'time': '1402',
#   'goals': '2',
#   'xG': '2.0381621811538935',
#   'assists': '4',
#   'xA': '5.772118408232927',
#   'shots': '31',
#   'key_passes': '27',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Everton',
#   'npg': '2',
#   'npxG': '2.0381621811538935',
#   'xGChain': '9.16857154481113',
#   'xGBuildup': '3.0818255096673965'},
#  {'id': '6857',
#   'player_name': 'Morgan Gibbs-White',
#   'games': '20',
#   'time': '1684',
#   'goals': '2',
#   'xG': '3.157539028674364',
#   'assists': '3',
#   'xA': '3.64912168122828',
#   'shots': '38',
#   'key_passes': '34',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '1',
#   'npxG': '2.3963702507317066',
#   'xGChain': '7.930424481630325',
#   'xGBuildup': '4.818683210760355'},
#  {'id': '6963',
#   'player_name': 'Justin Kluivert',
#   'games': '16',
#   'time': '930',
#   'goals': '2',
#   'xG': '2.163410298526287',
#   'assists': '0',
#   'xA': '0.6621727161109447',
#   'shots': '20',
#   'key_passes': '13',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Bournemouth',
#   'npg': '2',
#   'npxG': '2.163410298526287',
#   'xGChain': '4.608073219656944',
#   'xGBuildup': '2.0165402479469776'},
#  {'id': '7078',
#   'player_name': 'Sean Longstaff',
#   'games': '18',
#   'time': '1252',
#   'goals': '2',
#   'xG': '2.441285517066717',
#   'assists': '2',
#   'xA': '1.8700717370957136',
#   'shots': '17',
#   'key_passes': '12',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '2.441285517066717',
#   'xGChain': '9.028680991847068',
#   'xGBuildup': '6.250652589369565'},
#  {'id': '7365',
#   'player_name': 'Lucas Paquetá',
#   'games': '18',
#   'time': '1538',
#   'goals': '2',
#   'xG': '2.485358458943665',
#   'assists': '5',
#   'xA': '4.096440831199288',
#   'shots': '21',
#   'key_passes': '26',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'West Ham',
#   'npg': '1',
#   'npxG': '1.7241896213963628',
#   'xGChain': '7.715505393221974',
#   'xGBuildup': '3.421996710821986'},
#  {'id': '7382',
#   'player_name': 'Dan Burn',
#   'games': '16',
#   'time': '1363',
#   'goals': '2',
#   'xG': '2.7963957767933607',
#   'assists': '1',
#   'xA': '1.2153802886605263',
#   'shots': '11',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '2.7963957767933607',
#   'xGChain': '8.482227992266417',
#   'xGBuildup': '7.266240414232016'},
#  {'id': '7395',
#   'player_name': 'Carlos Vinicius',
#   'games': '13',
#   'time': '286',
#   'goals': '2',
#   'xG': '1.6243880316615105',
#   'assists': '0',
#   'xA': '0.5761066563427448',
#   'shots': '9',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Fulham',
#   'npg': '2',
#   'npxG': '1.6243880316615105',
#   'xGChain': '3.164248041808605',
#   'xGBuildup': '1.0699065858498216'},
#  {'id': '7762',
#   'player_name': 'Jean-Ricner Bellegarde',
#   'games': '11',
#   'time': '513',
#   'goals': '2',
#   'xG': '0.7283507473766804',
#   'assists': '1',
#   'xA': '0.639949057251215',
#   'shots': '8',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'D M S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '2',
#   'npxG': '0.7283507473766804',
#   'xGChain': '1.7606370151042938',
#   'xGBuildup': '0.922096561640501'},
#  {'id': '7967',
#   'player_name': 'Anssumane Fati',
#   'games': '9',
#   'time': '266',
#   'goals': '2',
#   'xG': '2.5193206518888474',
#   'assists': '0',
#   'xA': '0.4666708018630743',
#   'shots': '13',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Brighton',
#   'npg': '2',
#   'npxG': '2.5193206518888474',
#   'xGChain': '3.792191691696644',
#   'xGBuildup': '0.9694511890411377'},
#  {'id': '8252',
#   'player_name': 'Nicolás Domínguez',
#   'games': '12',
#   'time': '858',
#   'goals': '2',
#   'xG': '1.2517293933779001',
#   'assists': '0',
#   'xA': '0.1127941720187664',
#   'shots': '13',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '2',
#   'npxG': '1.2517293933779001',
#   'xGChain': '3.1391009632498026',
#   'xGBuildup': '2.0398145839571953'},
#  {'id': '8635',
#   'player_name': 'Sven Botman',
#   'games': '10',
#   'time': '767',
#   'goals': '2',
#   'xG': '0.8160056136548519',
#   'assists': '1',
#   'xA': '0.9268479347229004',
#   'shots': '7',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '0.8160056136548519',
#   'xGChain': '3.56592907756567',
#   'xGBuildup': '3.56592907756567'},
#  {'id': '8720',
#   'player_name': 'Jack Harrison',
#   'games': '15',
#   'time': '1220',
#   'goals': '2',
#   'xG': '2.511421412229538',
#   'assists': '3',
#   'xA': '3.276781279593706',
#   'shots': '16',
#   'key_passes': '16',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Everton',
#   'npg': '2',
#   'npxG': '2.511421412229538',
#   'xGChain': '6.504408955574036',
#   'xGBuildup': '1.783118700608611'},
#  {'id': '8812',
#   'player_name': 'Sasa Kalajdzic',
#   'games': '11',
#   'time': '132',
#   'goals': '2',
#   'xG': '1.3522434905171394',
#   'assists': '0',
#   'xA': '1.0801250115036964',
#   'shots': '4',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '2',
# ...
#   'games': '4',
#   'time': '188',
#   'goals': '0',
#   'xG': '0.047121964395046234',
#   'assists': '0',
#   'xA': '0.029761802405118942',
#   'shots': '1',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0.047121964395046234',
#   'xGChain': '0.25770944729447365',
#   'xGBuildup': '0.2279476448893547'},
#  {'id': '11707',
#   'player_name': 'Jurriën Timber',
#   'games': '1',
#   'time': '56',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Arsenal',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.19600066542625427',
#   'xGBuildup': '0.19600066542625427'},
#  {'id': '11709',
#   'player_name': 'Milos Kerkez',
#   'games': '15',
#   'time': '1176',
#   'goals': '0',
#   'xG': '0.21010207757353783',
#   'assists': '1',
#   'xA': '0.4846984539180994',
#   'shots': '4',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0.21010207757353783',
#   'xGChain': '3.313812365755439',
#   'xGBuildup': '2.9621767587959766'},
#  {'id': '11711',
#   'player_name': 'Bart Verbruggen',
#   'games': '9',
#   'time': '810',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.6037502512335777',
#   'xGBuildup': '1.6037502512335777'},
#  {'id': '11712',
#   'player_name': 'Thomas Kaminski',
#   'games': '20',
#   'time': '1800',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.6215326469391584',
#   'xGBuildup': '1.6215326469391584'},
#  {'id': '11713',
#   'player_name': 'Amari&#039;i Bell',
#   'games': '15',
#   'time': '1269',
#   'goals': '0',
#   'xG': '0.4993779337964952',
#   'assists': '0',
#   'xA': '0.31330371741205454',
#   'shots': '2',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0.4993779337964952',
#   'xGChain': '3.3982338942587376',
#   'xGBuildup': '2.5931895188987255'},
#  {'id': '11716',
#   'player_name': 'Pelly Ruddock Mpanzu',
#   'games': '16',
#   'time': '727',
#   'goals': '0',
#   'xG': '1.1216421527788043',
#   'assists': '0',
#   'xA': '0.49232789129018784',
#   'shots': '9',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '1.1216421527788043',
#   'xGChain': '2.2863366678357124',
#   'xGBuildup': '1.0027361810207367'},
#  {'id': '11721',
#   'player_name': 'Cauley Woodrow',
#   'games': '8',
#   'time': '51',
#   'goals': '0',
#   'xG': '0.3234410285949707',
#   'assists': '0',
#   'xA': '0.22639303468167782',
#   'shots': '5',
#   'key_passes': '5',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0.3234410285949707',
#   'xGChain': '0.4887387901544571',
#   'xGBuildup': '0.09787959977984428'},
#  {'id': '11722',
#   'player_name': 'Luke Berry',
#   'games': '3',
#   'time': '22',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11728',
#   'player_name': 'Calvin Bassey',
#   'games': '15',
#   'time': '1101',
#   'goals': '0',
#   'xG': '0.062184613198041916',
#   'assists': '0',
#   'xA': '0.10597540438175201',
#   'shots': '1',
#   'key_passes': '2',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'D S',
#   'team_title': 'Fulham',
#   'npg': '0',
#   'npxG': '0.062184613198041916',
#   'xGChain': '4.199875220656395',
#   'xGBuildup': '4.199875220656395'},
#  {'id': '11729',
#   'player_name': 'Bénie Traoré',
#   'games': '8',
#   'time': '360',
#   'goals': '0',
#   'xG': '0.3212226927280426',
#   'assists': '0',
#   'xA': '0.3953269124031067',
#   'shots': '1',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0.3212226927280426',
#   'xGChain': '1.2498194947838783',
#   'xGBuildup': '0.6901140883564949'},
#  {'id': '11730',
#   'player_name': 'Anis Ben Slimane',
#   'games': '10',
#   'time': '303',
#   'goals': '0',
#   'xG': '0.7071642503142357',
#   'assists': '0',
#   'xA': '0.48480090498924255',
#   'shots': '6',
#   'key_passes': '3',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0.7071642503142357',
#   'xGChain': '1.3688709884881973',
#   'xGBuildup': '0.2348492182791233'},
#  {'id': '11731',
#   'player_name': 'Andre Brooks',
#   'games': '9',
#   'time': '502',
#   'goals': '0',
#   'xG': '0.18827365711331367',
#   'assists': '0',
#   'xA': '0.06360763311386108',
#   'shots': '4',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0.18827365711331367',
#   'xGChain': '0.3025856204330921',
#   'xGBuildup': '0.13264136016368866'},
#  {'id': '11732',
#   'player_name': 'Auston Trusty',
#   'games': '16',
#   'time': '1261',
#   'goals': '0',
#   'xG': '0.5143859460949898',
#   'assists': '0',
#   'xA': '0.27174878120422363',
#   'shots': '5',
#   'key_passes': '2',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0.5143859460949898',
#   'xGChain': '0.7913954090327024',
#   'xGBuildup': '0.524194335564971'},
#  {'id': '11772',
#   'player_name': 'Yehor Yarmolyuk',
#   'games': '12',
#   'time': '339',
#   'goals': '0',
#   'xG': '0.820180157199502',
#   'assists': '0',
#   'xA': '0.05148041993379593',
#   'shots': '6',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Brentford',
#   'npg': '0',
#   'npxG': '0.820180157199502',
#   'xGChain': '1.3377937618643045',
#   'xGBuildup': '0.5040281042456627'},
#  {'id': '11807',
#   'player_name': 'Ian Maatsen',
#   'games': '12',
#   'time': '169',
#   'goals': '0',
#   'xG': '0.6834889836609364',
#   'assists': '0',
#   'xA': '0.05732445325702429',
#   'shots': '5',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0.6834889836609364',
#   'xGChain': '1.3501509558409452',
#   'xGBuildup': '0.6530423145741224'},
#  {'id': '11808',
#   'player_name': 'Andrey Santos',
#   'games': '1',
#   'time': '3',
#   'goals': '0',
#   'xG': '0.07211316376924515',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0.07211316376924515',
#   'xGChain': '0.027800722047686577',
#   'xGBuildup': '0.027800722047686577'},
#  {'id': '11810',
#   'player_name': 'Mason Burstow',
#   'games': '2',
#   'time': '2',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11811',
#   'player_name': 'James McConnell',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Liverpool',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11926',
#   'player_name': 'Edson Álvarez',
#   'games': '17',
#   'time': '1355',
#   'goals': '0',
#   'xG': '0.32052907440811396',
#   'assists': '1',
#   'xA': '0.13583909254521132',
#   'shots': '9',
#   'key_passes': '3',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'West Ham',
#   'npg': '0',
#   'npxG': '0.32052907440811396',
#   'xGChain': '3.1805523801594973',
#   'xGBuildup': '2.997342899441719'},
#  {'id': '11984',
#   'player_name': 'Youssef Chermiti',
#   'games': '7',
#   'time': '35',
#   'goals': '0',
#   'xG': '0.07689288537949324',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Everton',
#   'npg': '0',
#   'npxG': '0.07689288537949324',
#   'xGChain': '0.15150949731469154',
#   'xGBuildup': '0.14069579914212227'},
#  {'id': '11987',
#   'player_name': 'Daniel Gore',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Manchester United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11998',
#   'player_name': 'Hannes Delcroix',
#   'games': '9',
#   'time': '376',
#   'goals': '0',
#   'xG': '0.23279432207345963',
#   'assists': '0',
#   'xA': '0.13672708347439766',
#   'shots': '4',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0.23279432207345963',
#   'xGChain': '1.0179676115512848',
#   'xGBuildup': '0.8812405355274677'},
#  {'id': '12032',
#   'player_name': 'Djordje Petrovic',
#   'games': '6',
#   'time': '452',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'GK S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.2569560706615448',
#   'xGBuildup': '0.2569560706615448'},
#  {'id': '12033',
#   'player_name': 'Deivid Washington',
#   'games': '1',
#   'time': '6',
#   'goals': '0',
#   'xG': '0.12518750131130219',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0.12518750131130219',
#   'xGChain': '0.12518750131130219',
#   'xGBuildup': '0'},
#  {'id': '12034',
#   'player_name': 'Brandon Aguilera',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12086',
#   'player_name': 'Alex Matos',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12094',
#   'player_name': 'Mike Trésor',
#   'games': '14',
#   'time': '376',
#   'goals': '0',
#   'xG': '0.6615988579578698',
#   'assists': '0',
#   'xA': '0.6491026850417256',
#   'shots': '5',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0.6615988579578698',
#   'xGChain': '0.9640207779593766',
#   'xGBuildup': '0.3211935800500214'},
#  {'id': '12118',
#   'player_name': 'Jamie Donley',
#   'games': '2',
#   'time': '2',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Tottenham',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12123',
#   'player_name': 'Murillo',
#   'games': '15',
#   'time': '1333',
#   'goals': '0',
#   'xG': '0.7743317726999521',
#   'assists': '1',
#   'xA': '1.0338670872151852',
#   'shots': '8',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0.7743317726999521',
#   'xGChain': '4.068312864750624',
#   'xGBuildup': '3.109786381945014'},
#  {'id': '12152',
#   'player_name': 'Matheus França',
#   'games': '6',
#   'time': '40',
#   'goals': '0',
#   'xG': '0.09937552036717534',
#   'assists': '0',
#   'xA': '0.22760880179703236',
#   'shots': '3',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Crystal Palace',
#   'npg': '0',
#   'npxG': '0.09937552036717534',
#   'xGChain': '0.27308147959411144',
#   'xGBuildup': '0.05349571630358696'},
#  {'id': '12158',
#   'player_name': 'Ryan Oné',
#   'games': '1',
#   'time': '4',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12187',
#   'player_name': 'Jordan Clark',
#   'games': '6',
#   'time': '149',
#   'goals': '0',
#   'xG': '0.1283271759748459',
#   'assists': '0',
#   'xA': '0.028225945308804512',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Luton',
#   'npg': '0',
#   'npxG': '0.1283271759748459',
#   'xGChain': '0.35226775892078876',
#   'xGBuildup': '0.19571463763713837'},
#  {'id': '12198',
#   'player_name': 'Ben Parkinson',
#   'games': '1',
#   'time': '18',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12199',
#   'player_name': 'Alex Murphy',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12200',
#   'player_name': 'Amadou Diallo',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12204',
#   'player_name': 'Benicio Baker-Boaitey',
#   'games': '2',
#   'time': '2',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.1531512588262558',
#   'xGBuildup': '0.1531512588262558'},
#  {'id': '12215',
#   'player_name': 'Michael Ndiweni',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12251',
#   'player_name': 'Sydie Peck',
#   'games': '1',
#   'time': '6',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '12275',
#   'player_name': 'Willy Kambwala',
#   'games': '2',
#   'time': '88',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Manchester United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.07591637223958969',
#   'xGBuildup': '0.07591637223958969'},
#  {'id': '12291',
#   'player_name': 'Rhys Norrington-Davies',
#   'games': '2',
#   'time': '9',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Sheffield United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'}]

# %%
cols = list(e[0].keys())
vals = []

for x in e:
    vals.append(list(x.values()))

players_df = pd.DataFrame(vals, columns = cols)

# %%
players_df
# Out:
#         id             player_name games  time goals                  xG  \
# 0     1250           Mohamed Salah    20  1768    14  13.610325902700424
# 1     8260          Erling Haaland    15  1305    14  16.727499932050705
# 2      453           Son Heung-Min    20  1739    12    7.47495724260807
# 3     1679         Dominic Solanke    20  1793    12  12.433437447994947
# 4     1776            Jarrod Bowen    20  1800    11   8.646546997129917
# ..     ...                     ...   ...   ...   ...                 ...
# 510  12204   Benicio Baker-Boaitey     2     2     0                   0
# 511  12215         Michael Ndiweni     1     1     0                   0
# 512  12251              Sydie Peck     1     6     0                   0
# 513  12275          Willy Kambwala     2    88     0                   0
# 514  12291  Rhys Norrington-Davies     2     9     0                   0
#
#     assists                  xA shots key_passes yellow_cards red_cards  \
# 0         8    9.57847910746932    65         47            2         0
# 1         4  3.2472310978919268    58         16            1         0
# 2         5   6.843130592256784    52         37            1         0
# 3         1  0.9976950995624065    67         14            1         0
# 4         2   3.144163405522704    51         14            1         0
# ..      ...                 ...   ...        ...          ...       ...
# 510       0                   0     0          0            0         0
# 511       0                   0     0          0            0         0
# 512       0                   0     0          0            0         0
# 513       0                   0     0          0            0         0
# 514       0                   0     0          0            0         0
#
#     position         team_title npg                npxG              xGChain  \
# 0          F          Liverpool  10   9.043387070298195    19.68034301698208
# 1          F    Manchester City  11   13.68282476067543   16.214465029537678
# 2        F M          Tottenham  11   6.713788405060768   16.887082293629646
# 3          F        Bournemouth  11  11.672268595546484     12.4195606559515
# 4        F M           West Ham  11   8.646546997129917    10.23329196497798
# ..       ...                ...  ..                 ...                  ...
# 510        S           Brighton   0                   0   0.1531512588262558
# 511        S   Newcastle United   0                   0                    0
# 512        S   Sheffield United   0                   0                    0
# 513      D S  Manchester United   0                   0  0.07591637223958969
# 514        S   Sheffield United   0                   0                    0
#
#                xGBuildup
# 0      5.720102474093437
# 1     1.3705047406256199
# 2      6.178518561646342
# 3     1.9994132556021214
# 4      2.032880038022995
# ..                   ...
# 510   0.1531512588262558
# 511                    0
# 512                    0
# 513  0.07591637223958969
# 514                    0
#
# [515 rows x 18 columns]

# %%
async def league_table():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        table = await understat.get_league_table("EPL", "2024")
        league_table_df = pd.DataFrame(table[1:], columns = table[0])
        return league_table_df

league_table_df = asyncio.run(league_table())
league_table_df["Position"] = np.arange(1,21)

# %%
league_table_df
# Out:
#                        Team   M   W  D   L   G  GA  PTS     xG   NPxG    xGA  \
# 0                 Liverpool  21  14  6   1  47  18   48  47.84  42.99  25.71
# 1           Manchester City  20  13  4   3  48  23   43  45.34  41.54  19.74
# 2                   Arsenal  21  13  4   4  42  20   43  44.08  39.51  20.00
# 3               Aston Villa  21  13  4   4  43  27   43  39.87  36.82  28.86
# 4                 Tottenham  21  12  4   5  44  31   40  38.99  38.23  37.58
# 5                  West Ham  21  10  5   6  35  32   35  31.83  29.55  39.10
# 6         Manchester United  21  10  2   9  24  29   32  30.22  27.92  36.87
# 7                  Brighton  20   8  7   5  38  33   31  36.65  33.61  31.77
# 8                   Chelsea  21   9  4   8  35  31   31  44.01  37.92  31.27
# 9          Newcastle United  21   9  2  10  41  32   29  44.86  41.81  36.48
# 10  Wolverhampton Wanderers  20   8  4   8  30  31   28  28.56  27.79  35.79
# 11                  Everton  21   8  3  10  24  28   27  34.99  34.99  31.50
# 12              Bournemouth  20   7  4   9  28  39   25  31.43  30.67  35.65
# 13                   Fulham  21   7  3  11  28  36   24  26.57  25.04  37.86
# 14                Brentford  20   6  4  10  29  33   22  36.71  34.43  27.49
# 15           Crystal Palace  21   5  6  10  22  34   21  27.42  25.13  34.97
# 16        Nottingham Forest  21   5  5  11  26  38   20  25.74  24.98  34.03
# 17                    Luton  20   4  4  12  24  38   16  24.24  22.72  48.66
# 18                  Burnley  21   3  3  15  21  42   12  21.17  20.41  39.35
# 19         Sheffield United  21   2  4  15  17  51   10  19.92  17.64  47.76
#
#     NPxGA  NPxGD   PPDA  OPPDA   DC  ODC   xPTS  Position
# 0   24.95  18.04   8.05  16.15  257  127  40.75         1
# 1   18.22  23.32  11.58  20.87  245   88  43.09         2
# 2   18.48  21.03   9.13  16.91  245   91  42.17         3
# 3   28.86   7.97  12.43  10.27  213  131  37.00         4
# 4   33.78   4.45   8.21  11.20  273  151  31.11         5
# 5   35.29  -5.75  17.08   9.81   95  227  25.13         6
# 6   35.35  -7.43  12.05  13.21  184  167  24.79         7
# 7   27.97   5.64   9.18  17.07  219  179  30.50         8
# 8   28.97   8.95   8.88  14.07  222  136  36.80         9
# 9   34.07   7.75  10.21  11.64  181  154  35.13        10
# 10  31.98  -4.19  12.21   9.67  122  195  22.88        11
# 11  27.69   7.30  13.49   9.91  127  173  31.52        12
# 12  33.21  -2.54  10.58   8.19  164  217  26.20        13
# 13  33.29  -8.25  13.30  13.13  154  180  23.25        14
# 14  26.73   7.70   9.39  11.12  151  172  31.96        15
# 15  32.68  -7.55  13.58   8.59  131  193  24.84        16
# 16  31.75  -6.76  17.71  10.12  116  195  23.81        17
# 17  47.90 -25.18  14.79   7.53   89  198  15.53        18
# 18  37.06 -16.65  13.96  12.88  102  203  17.71        19
# 19  45.48 -27.84  15.59   8.62   92  205  14.16        20

# %%
total_shots = []
players_id = list(players_df["id"])


async def get_player_shots(player_id):
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        shots = await understat.get_player_shots(
            player_id
        )
        return json.dumps(shots)
for x in players_id:
    shots = asyncio.run(get_player_shots(x))
    shots = json.loads(shots)
    total_shots.append(shots)

# %%
def flatten_extend(matrix):
    flat_list = []
    for row in matrix:
        flat_list.extend(row)
    return flat_list

total_shots = flatten_extend(total_shots)

# %%
cols2 = list(total_shots[0].keys())
vals2 = []

for x in total_shots:
    vals2.append(list(x.values()))

total_player_shots_df = pd.DataFrame(vals2, columns = cols2)

# %%
total_player_shots_df['date']= pd.to_datetime(total_player_shots_df['date'])
total_player_shots_df = total_player_shots_df[total_player_shots_df["date"] > '2023-07-01']

# %%
total_player_shots_df
# Out:
#            id minute       result                   X                    Y  \
# 985    532588     11   ShotOnPost  0.8190000152587891   0.5279999923706055
# 986    532592     25  BlockedShot   0.850999984741211                0.445
# 987    532594     40  MissedShots  0.8590000152587891                0.315
# 988    533205     33  MissedShots  0.8190000152587891   0.5720000076293945
# 989    533207     35         Goal  0.9569999694824218   0.5259999847412109
# ...       ...    ...          ...                 ...                  ...
# 51496  544109     76  MissedShots  0.6859999847412109   0.5079999923706054
# 51497  545174    101  MissedShots  0.9330000305175781   0.6270000076293946
# 51498  556621     96  BlockedShot  0.8019999694824219                0.655
# 51499  557870     40  BlockedShot  0.9119999694824219   0.3870000076293945
# 51500  557877     57  MissedShots  0.8209999847412109  0.32299999237060545
#
#                           xG          player h_a player_id situation season  \
# 985      0.06408040970563889   Mohamed Salah   a      1250  OpenPlay   2023
# 986      0.10087071359157562   Mohamed Salah   a      1250  OpenPlay   2023
# 987      0.04292548820376396   Mohamed Salah   a      1250  OpenPlay   2023
# 988      0.05514945462346077   Mohamed Salah   h      1250  OpenPlay   2023
# 989       0.6668094396591187   Mohamed Salah   h      1250  SetPiece   2023
# ...                      ...             ...  ..       ...       ...    ...
# 51496  0.0074213468469679356  Matheus França   a     12152  OpenPlay   2023
# 51497     0.0706448033452034  Matheus França   h     12152  OpenPlay   2023
# 51498   0.021309370175004005  Matheus França   a     12152  OpenPlay   2023
# 51499    0.09613598138093948    Jordan Clark   a     12187  OpenPlay   2023
# 51500   0.032191190868616104    Jordan Clark   a     12187  OpenPlay   2023
#
#         shotType match_id            h_team          a_team h_goals a_goals  \
# 985    RightFoot    22283           Chelsea       Liverpool       1       1
# 986     LeftFoot    22283           Chelsea       Liverpool       1       1
# 987     LeftFoot    22283           Chelsea       Liverpool       1       1
# 988     LeftFoot    22288         Liverpool     Bournemouth       3       1
# 989     LeftFoot    22288         Liverpool     Bournemouth       3       1
# ...          ...      ...               ...             ...     ...     ...
# 51496  RightFoot    21981  Newcastle United  Crystal Palace       4       0
# 51497   LeftFoot    21990    Crystal Palace       Tottenham       1       2
# 51498  RightFoot    22080           Chelsea  Crystal Palace       2       1
# 51499  RightFoot    22096           Burnley           Luton       1       1
# 51500  RightFoot    22096           Burnley           Luton       1       1
#
#                      date        player_assisted lastAction
# 985   2023-08-13 15:30:00             Cody Gakpo       Pass
# 986   2023-08-13 15:30:00              Luis Díaz       Pass
# 987   2023-08-13 15:30:00                   None       None
# 988   2023-08-19 14:00:00             Diogo Jota       Pass
# 989   2023-08-19 14:00:00                   None    Rebound
# ...                   ...                    ...        ...
# 51496 2023-10-21 14:00:00  Cheick Oumar Doucoure       None
# 51497 2023-10-27 19:00:00   Jean-Philippe Mateta   HeadPass
# 51498 2023-12-27 19:30:00          Michael Olise    Chipped
# 51499 2024-01-12 19:45:00       Chiedozie Ogbene       Pass
# 51500 2024-01-12 19:45:00           Ross Barkley    Chipped
#
# [5624 rows x 20 columns]

# %%
async def league_results():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        fixtures = await understat.get_league_results(
            "epl",
            2024,
            {
            }
        )
        return(json.dumps(fixtures))

matches = asyncio.run(league_results())
matches = json.loads(matches)

# %%
cols3 = list(matches[0].keys())
vals3 = []

for x in matches:
    vals3.append(list(x.values()))

matches_df = pd.DataFrame(vals3, columns = cols3)

# %%
def match_parser(row):
    row["home_id"] = row["h"]["id"]
    row["away_id"] = row["a"]["id"]
    row["home_team"] = row["h"]["title"]
    row["away_team"] = row["a"]["title"]
    row["home_goals"] = row["goals"]["h"]
    row["away_goals"] = row["goals"]["a"]
    row["home_xg"] = row["xG"]["h"]
    row["away_xg"] = row["xG"]["a"]
    if row["home_goals"] == row["away_goals"]:
        row["is_draw"] = True
    else:
        row["is_draw"] = False
    if row["home_goals"] > row["away_goals"]:
        row["home_win"] = True
    else:
        row["home_win"] = False
    if row["home_goals"] < row["away_goals"]:
        row["away_win"] = True
    else:
        row["away_win"] = False
    return row

matches_df = matches_df.apply(lambda x: match_parser(x), axis=1)

# %%
matches_df
# Out:
#         id  isResult                                                  h  \
# 0    22275      True  {'id': '92', 'title': 'Burnley', 'short_title'...
# 1    22276      True  {'id': '83', 'title': 'Arsenal', 'short_title'...
# 2    22277      True  {'id': '73', 'title': 'Bournemouth', 'short_ti...
# 3    22278      True  {'id': '220', 'title': 'Brighton', 'short_titl...
# 4    22279      True  {'id': '72', 'title': 'Everton', 'short_title'...
# ..     ...       ...                                                ...
# 202  22099      True  {'id': '89', 'title': 'Manchester United', 'sh...
# 203  22103      True  {'id': '83', 'title': 'Arsenal', 'short_title'...
# 204  22104      True  {'id': '244', 'title': 'Brentford', 'short_tit...
# 205  22101      True  {'id': '238', 'title': 'Sheffield United', 'sh...
# 206  22102      True  {'id': '73', 'title': 'Bournemouth', 'short_ti...
#
#                                                      a                 goals  \
# 0    {'id': '88', 'title': 'Manchester City', 'shor...  {'h': '0', 'a': '3'}
# 1    {'id': '249', 'title': 'Nottingham Forest', 's...  {'h': '2', 'a': '1'}
# 2    {'id': '81', 'title': 'West Ham', 'short_title...  {'h': '1', 'a': '1'}
# 3    {'id': '256', 'title': 'Luton', 'short_title':...  {'h': '4', 'a': '1'}
# 4    {'id': '228', 'title': 'Fulham', 'short_title'...  {'h': '0', 'a': '1'}
# ..                                                 ...                   ...
# 202  {'id': '82', 'title': 'Tottenham', 'short_titl...  {'h': '2', 'a': '2'}
# 203  {'id': '78', 'title': 'Crystal Palace', 'short...  {'h': '5', 'a': '0'}
# 204  {'id': '249', 'title': 'Nottingham Forest', 's...  {'h': '3', 'a': '2'}
# 205  {'id': '81', 'title': 'West Ham', 'short_title...  {'h': '2', 'a': '2'}
# 206  {'id': '87', 'title': 'Liverpool', 'short_titl...  {'h': '0', 'a': '4'}
#
#                                     xG             datetime  \
# 0    {'h': '0.311032', 'a': '2.40074'}  2023-08-11 19:00:00
# 1    {'h': '0.84262', 'a': '0.966305'}  2023-08-12 11:30:00
# 2      {'h': '1.51025', 'a': '1.4834'}  2023-08-12 14:00:00
# 3     {'h': '4.36748', 'a': '1.88594'}  2023-08-12 14:00:00
# 4     {'h': '2.59001', 'a': '1.58144'}  2023-08-12 14:00:00
# ..                                 ...                  ...
# 202  {'h': '0.923233', 'a': '1.31224'}  2024-01-14 16:30:00
# 203  {'h': '3.52167', 'a': '0.288083'}  2024-01-20 12:30:00
# 204   {'h': '1.94219', 'a': '1.22251'}  2024-01-20 17:30:00
# 205    {'h': '2.61362', 'a': '2.4241'}  2024-01-21 14:00:00
# 206  {'h': '0.834585', 'a': '1.53344'}  2024-01-21 16:30:00
#
#                                           forecast home_id away_id  \
# 0    {'w': '0.0177', 'd': '0.0854', 'l': '0.8969'}      92      88
# 1     {'w': '0.2797', 'd': '0.3363', 'l': '0.384'}      83     249
# 2    {'w': '0.3559', 'd': '0.3169', 'l': '0.3272'}      73      81
# 3     {'w': '0.879', 'd': '0.0876', 'l': '0.0334'}     220     256
# 4     {'w': '0.6371', 'd': '0.1989', 'l': '0.164'}      72     228
# ..                                             ...     ...     ...
# 202  {'w': '0.2351', 'd': '0.3057', 'l': '0.4592'}      89      82
# 203     {'w': '0.967', 'd': '0.029', 'l': '0.004'}      83      78
# 204   {'w': '0.5612', 'd': '0.2428', 'l': '0.196'}     244     249
# 205  {'w': '0.4271', 'd': '0.2342', 'l': '0.3387'}     238      81
# 206  {'w': '0.1701', 'd': '0.2667', 'l': '0.5632'}      73      87
#
#              home_team          away_team home_goals away_goals   home_xg  \
# 0              Burnley    Manchester City          0          3  0.311032
# 1              Arsenal  Nottingham Forest          2          1   0.84262
# 2          Bournemouth           West Ham          1          1   1.51025
# 3             Brighton              Luton          4          1   4.36748
# 4              Everton             Fulham          0          1   2.59001
# ..                 ...                ...        ...        ...       ...
# 202  Manchester United          Tottenham          2          2  0.923233
# 203            Arsenal     Crystal Palace          5          0   3.52167
# 204          Brentford  Nottingham Forest          3          2   1.94219
# 205   Sheffield United           West Ham          2          2   2.61362
# 206        Bournemouth          Liverpool          0          4  0.834585
#
#       away_xg  is_draw  home_win  away_win
# 0     2.40074    False     False      True
# 1    0.966305    False      True     False
# 2      1.4834     True     False     False
# 3     1.88594    False      True     False
# 4     1.58144    False     False      True
# ..        ...      ...       ...       ...
# 202   1.31224     True     False     False
# 203  0.288083    False      True     False
# 204   1.22251    False      True     False
# 205    2.4241     True     False     False
# 206   1.53344    False     False      True
#
# [207 rows x 19 columns]
